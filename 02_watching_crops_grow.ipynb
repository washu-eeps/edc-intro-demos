# %% [markdown]
# ## Notebook 2: Watching Crops Grow from Space
#
# **Can we watch crops grow from space?**
#
# In the previous notebook, we computed a single NDVI snapshot. But vegetation changes throughout the year. In this notebook, we'll:
#
# - Create monthly NDVI composites across the growing season
# - Compare early vs. peak season side-by-side
# - Generate an animated GIF showing vegetation change over time

# %% [markdown]
# ## Setup
#
# Same initialization as Notebook 01.

# %%
# %pip install -q geemap folium
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import ee
from IPython.display import Image, display

# Initialize Earth Engine
PROJECT = "eeps-geospatial"
BUCKET = "wustl-eeps-edc"
ee.Initialize(project=PROJECT)

import geemap.foliumap as geemap

print("Ready!")
# Out:
# Ready!

# %% [markdown]
# ## Define area of interest
#
# We'll use Missouri again from the TIGER dataset.

# %%
states = ee.FeatureCollection("TIGER/2018/States")
mo = states.filter(ee.Filter.eq("NAME", "Missouri")).geometry()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Same helper functions from Notebook 01 - repeated here for standalone use

def mask_s2_clouds(img):
    """Mask clouds using Sentinel-2 Scene Classification Layer."""
    scl = img.select("SCL")
    mask = scl.neq(3).And(scl.neq(8)).And(scl.neq(9)).And(scl.neq(10)).And(scl.neq(11))
    return img.updateMask(mask)

def add_ndvi(img):
    """Add NDVI band to image."""
    ndvi = img.normalizedDifference(["B8", "B4"]).rename("NDVI")
    return img.addBands(ndvi)

# NDVI color palette
ndvi_palette = ['#d73027', '#fc8d59', '#fee08b', '#d9ef8b', '#91cf60', '#1a9850']
ndvi_vis = {"min": 0.0, "max": 0.8, "palette": ndvi_palette}
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Create monthly NDVI composites
#
# We'll generate one NDVI composite per month from April through October 2024 - the agricultural growing season in Missouri.

# %%
s2 = ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED")

# Months to process (Apr-Oct 2024)
months = [
    ("2024-04-01", "2024-04-30", "April"),
    ("2024-05-01", "2024-05-31", "May"),
    ("2024-06-01", "2024-06-30", "June"),
    ("2024-07-01", "2024-07-31", "July"),
    ("2024-08-01", "2024-08-31", "August"),
    ("2024-09-01", "2024-09-30", "September"),
    ("2024-10-01", "2024-10-31", "October"),
]

def get_monthly_ndvi(start, end, label):
    """Create median NDVI composite for a date range."""
    composite = (
        s2.filterBounds(mo)
          .filterDate(start, end)
          .map(mask_s2_clouds)
          .map(add_ndvi)
          .select("NDVI")
          .median()
          .clip(mo)
    )
    return composite.set("month", label)

# Build list of monthly composites
monthly_ndvi = [get_monthly_ndvi(start, end, label) for start, end, label in months]

print(f"Created {len(monthly_ndvi)} monthly composites")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Created 7 monthly composites

# %% [markdown]
# ## Compare April vs. July
#
# Early spring vs. peak growing season - you should see a dramatic difference in vegetation.

# %%
# April (index 0) vs July (index 3)
april_ndvi = monthly_ndvi[0]
july_ndvi = monthly_ndvi[3]

# Create side-by-side maps
left_layer = geemap.ee_tile_layer(april_ndvi, ndvi_vis, "April 2024")
right_layer = geemap.ee_tile_layer(july_ndvi, ndvi_vis, "July 2024")

m = geemap.Map(center=[38.5, -92.5], zoom=7)
m.split_map(left_layer, right_layer)
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7ff60c3ac979741c2d612a458cb2fe6d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/digidem/leaflet-side-by-side@2.0.0/leaflet-side-by-side.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7ff60c3ac979741c2d612a458cb2fe6d&quot; &gt;&lt;/div&gt;
#
#
#
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7ff60c3ac979741c2d612a458cb2fe6d = L.map(
#                 &quot;map_7ff60c3ac979741c2d612a458cb2fe6d&quot;,
#                 {
#                     center: [38.5, -92.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;eeInitialize&quot;: true,
#   &quot;addGoogleMap&quot;: false,
#   &quot;pluginLatlngpopup&quot;: false,
#   &quot;pluginFullscreen&quot;: true,
#   &quot;pluginDraw&quot;: true,
#   &quot;DrawExport&quot;: false,
#   &quot;pluginMinimap&quot;: false,
#   &quot;locateControl&quot;: false,
#   &quot;searchControl&quot;: true,
#   &quot;basemap&quot;: &quot;OpenStreetMap&quot;,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3a602ba2cedb2f0b8dc5e346dde3c650 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;OpenStreetMap&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3a602ba2cedb2f0b8dc5e346dde3c650.addTo(map_7ff60c3ac979741c2d612a458cb2fe6d);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_7ff60c3ac979741c2d612a458cb2fe6d);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#                 // FeatureGroup is to store editable layers.
#                 var drawnItems_draw_control_5400fb7cbb462f4a0dd01960ed108632 =
#                     new L.featureGroup().addTo(
#                         map_7ff60c3ac979741c2d612a458cb2fe6d
#                     );
#
#             options.edit.featureGroup = drawnItems_draw_control_5400fb7cbb462f4a0dd01960ed108632;
#             var draw_control_5400fb7cbb462f4a0dd01960ed108632 = new L.Control.Draw(
#                 options
#             ).addTo( map_7ff60c3ac979741c2d612a458cb2fe6d );
#             map_7ff60c3ac979741c2d612a458cb2fe6d.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_5400fb7cbb462f4a0dd01960ed108632.addLayer(layer);
#             });
#             map_7ff60c3ac979741c2d612a458cb2fe6d.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_5400fb7cbb462f4a0dd01960ed108632.addLayer(e.layer);
#             });
#
#
#
#
#
#             var geocoderOpts_geocoder_7084c28040db754f130605cdb5341225 = {
#   &quot;collapsed&quot;: true,
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;defaultMarkGeocode&quot;: true,
#   &quot;zoom&quot;: 11,
#   &quot;provider&quot;: &quot;nominatim&quot;,
#   &quot;providerOptions&quot;: {
# },
# };
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_7084c28040db754f130605cdb5341225 = geocoderOpts_geocoder_7084c28040db754f130605cdb5341225[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_7084c28040db754f130605cdb5341225 = L.Control.Geocoder[ geocoderName_geocoder_7084c28040db754f130605cdb5341225 ](
#                 geocoderOpts_geocoder_7084c28040db754f130605cdb5341225[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_7084c28040db754f130605cdb5341225[&quot;geocoder&quot;] = customGeocoder_geocoder_7084c28040db754f130605cdb5341225;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_7084c28040db754f130605cdb5341225
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocode

# %% [markdown]
# ## Generate animated GIF
#
# Now let's create an animation showing all seven months. We'll use Earth Engine's `getVideoThumbURL()` to generate the GIF server-side.

# %%
# Convert list to ImageCollection for animation
ndvi_collection = ee.ImageCollection.fromImages(monthly_ndvi)

# Use Missouri's bounding box for the animation region
region = mo.bounds()

# Animation parameters
animation_params = {
    'region': region,
    'dimensions': 600,
    'crs': 'EPSG:4326',
    'framesPerSecond': 1,
    'min': 0.0,
    'max': 0.8,
    'palette': ndvi_palette
}

# Generate the animation URL
gif_url = ndvi_collection.getVideoThumbURL(animation_params)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Display the animation
#
# Watch Missouri green up from April through July, then begin to brown as crops mature and are harvested.

# %%
display(Image(url=gif_url))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <img src="https://earthengine.googleapis.com/v1/projects/eeps-geospatial/videoThumbnails/59cb8a59187b2448c7a01c8f3695a780-6a2502d416ef4bdd3c27b00b96e3a6c9:getPixels"/>

# %% [markdown]
# ## Try it yourself
#
# Ideas to extend this notebook:
#
# 1. **Different state** - Change the filter to another agricultural state (Iowa, Kansas, Nebraska)
# 2. **Different year** - Compare 2024 to a drought year
# 3. **Zoom in** - Pick a specific county or draw a custom region
# 4. **Change the speed** - Adjust `framesPerSecond` in the animation parameters
# 5. **Export the GIF** - Save the animation to Google Cloud Storage for use elsewhere
