# %% [markdown]
# ## Notebook 6: Ocean Color and Sea Surface Temperature
#
# **The ocean isn't just blue - from space we can see where life thrives.**
#
# When you look at the ocean from a plane, you might notice patches of different colors - turquoise near the coast, deep blue offshore, and sometimes greenish bands. These aren't random variations. They reveal the invisible world of **phytoplankton** - microscopic plants that form the base of the entire ocean food chain.
#
# Satellites measure **ocean color** to estimate chlorophyll concentration, which tells us where phytoplankton are blooming. They also measure **sea surface temperature (SST)**, which affects marine life distribution and ocean circulation.
#
# In this notebook, we'll:
#
# - Visualize chlorophyll-a concentration along the Gulf Coast
# - Map sea surface temperature patterns
# - Compare summer vs. winter conditions
# - See how the Mississippi River creates a productivity hotspot
#
# This is how scientists monitor ocean health, track harmful algal blooms, and study the impacts of climate change on marine ecosystems.

# %% [markdown]
# ## Setup
#
# Same initialization as previous notebooks.

# %%
# %pip install -q geemap folium
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Note: you may need to restart the kernel to use updated packages.

# %%
import ee
from google.cloud import storage

# Initialize Earth Engine
PROJECT = "eeps-geospatial"
BUCKET = "wustl-eeps-edc"
ee.Initialize(project=PROJECT)

import geemap.foliumap as geemap

print("Ready!")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Ready!

# %% [markdown]
# ## What is ocean color?
#
# **Ocean color** refers to the subtle variations in how the ocean reflects sunlight. Pure open-ocean water appears deep blue because water absorbs red light and scatters blue. But when phytoplankton are present, they add green to the mix.
#
# **Chlorophyll-a** is the key measurement:
# - It's the primary photosynthetic pigment in phytoplankton
# - Higher chlorophyll = more phytoplankton = greener water
# - Measured in **mg/m³** (milligrams per cubic meter)
#
# **Why does this matter?**
# - Phytoplankton produce ~50% of Earth's oxygen through photosynthesis
# - They're the base of the marine food chain (phytoplankton → zooplankton → fish → whales)
# - High productivity areas = good fishing grounds
# - Too much = harmful algal blooms (red tides)
#
# **What drives phytoplankton blooms?**
# - **Nutrients**: Nitrogen, phosphorus from rivers, upwelling, or mixing
# - **Light**: Sunlight for photosynthesis
# - **Temperature**: Affects growth rates and stratification
#
# The Mississippi River is a major nutrient source, making the northern Gulf Coast one of the most productive (and problematic) coastal areas in the US.

# %% [markdown]
# ## Define area of interest: Gulf Coast
#
# We'll focus on the Gulf Coast waters from Texas to Florida. This region receives freshwater and nutrients from major rivers including the Mississippi, the largest river system in North America.

# %%
# Gulf Coast bounding box
gulf_coast = ee.Geometry.Rectangle([-98, 18, -80, 31])

# Key locations for reference
landmarks = {
    "Mississippi Delta": [-89.5, 29.0],
    "New Orleans": [-90.07, 29.95],
    "Tampa Bay": [-82.5, 27.8],
    "Corpus Christi": [-97.4, 27.8],
    "Cancun": [-86.85, 21.16],
}

# Center point for maps
center_lat = 25.5
center_lon = -89

print("Area of interest: Gulf Coast")
print("Key feature: Mississippi River plume brings nutrients into coastal waters")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Area of interest: Gulf Coast
# Key feature: Mississippi River plume brings nutrients into coastal waters

# %% [markdown]
# ## Load MODIS Ocean Color data
#
# NASA's MODIS-Aqua satellite has been measuring ocean color since 2002. The **L3SMI** (Level 3 Standard Mapped Image) product provides global daily composites of chlorophyll-a concentration.
#
# We'll compare two seasons:
# - **Winter (Jan-Feb)**: Strong mixing brings nutrients up from deep water
# - **Summer (Jul-Aug)**: Warmer, more stratified - Mississippi plume effects more visible

# %%
# MODIS Ocean Color - Chlorophyll-a concentration
ocean_color = ee.ImageCollection("NASA/OCEANDATA/MODIS-Aqua/L3SMI")

# Use 2021 (most recent complete year available in GEE)
year = 2021

# Winter composite (January-February)
winter_chl = (
    ocean_color
    .filterDate(f"{year}-01-01", f"{year}-02-28")
    .select("chlor_a")  # Chlorophyll-a concentration in mg/m³
    .median()
    .clip(gulf_coast)
)

# Summer composite (July-August)
summer_chl = (
    ocean_color
    .filterDate(f"{year}-07-01", f"{year}-08-31")
    .select("chlor_a")
    .median()
    .clip(gulf_coast)
)

print(f"Loaded chlorophyll-a data for winter and summer {year}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Loaded chlorophyll-a data for winter and summer 2021

# %% [markdown]
# ## Visualize chlorophyll concentration
#
# Chlorophyll-a values vary over orders of magnitude:
# - **< 0.1 mg/m³**: Ultra-oligotrophic (nutrient-poor) open ocean - deep blue
# - **0.1 - 1 mg/m³**: Typical open ocean
# - **1 - 10 mg/m³**: Productive coastal and upwelling areas
# - **> 10 mg/m³**: Very high productivity, potential algal blooms
#
# We use a logarithmic color scale because of this wide range.

# %%
# Chlorophyll palette: purple (low) → blue → green → yellow (high)
chl_palette = [
    '#2c0a4a',  # Dark purple - very low
    '#4a1486',  # Purple
    '#0d47a1',  # Dark blue
    '#1976d2',  # Blue
    '#00acc1',  # Cyan
    '#00897b',  # Teal
    '#43a047',  # Green
    '#7cb342',  # Light green
    '#c0ca33',  # Yellow-green
    '#fdd835',  # Yellow
    '#ff8f00',  # Orange - high
]

# Use log scale for chlorophyll (0.01 to 30 mg/m³)
# Taking log10: log10(0.01) = -2, log10(30) ≈ 1.5
chl_log = summer_chl.log10()

chl_vis = {
    'min': -2,  # 0.01 mg/m³
    'max': 1.5, # ~30 mg/m³
    'palette': chl_palette
}

# Create map
m = geemap.Map(center=[center_lat, center_lon], zoom=5)

# Add chlorophyll layer
m.addLayer(chl_log, chl_vis, f'Chlorophyll-a Summer {year}')

# Add landmarks
for name, coords in landmarks.items():
    point = ee.Geometry.Point(coords)
    m.addLayer(point, {'color': 'white'}, name)

# Add region boundary
m.addLayer(gulf_coast, {'color': 'white'}, 'Gulf Coast', False)

m.add_colorbar(
    chl_vis, 
    label='Chlorophyll-a (log10 mg/m³)', 
    layer_name=f'Chlorophyll-a Summer {year}'
)

m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d1941149f8adbb29a90b660dc1bcef00 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d1941149f8adbb29a90b660dc1bcef00&quot; &gt;&lt;/div&gt;
#
#
#
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d1941149f8adbb29a90b660dc1bcef00 = L.map(
#                 &quot;map_d1941149f8adbb29a90b660dc1bcef00&quot;,
#                 {
#                     center: [25.5, -89.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;eeInitialize&quot;: true,
#   &quot;addGoogleMap&quot;: false,
#   &quot;pluginLatlngpopup&quot;: false,
#   &quot;pluginFullscreen&quot;: true,
#   &quot;pluginDraw&quot;: true,
#   &quot;DrawExport&quot;: false,
#   &quot;pluginMinimap&quot;: false,
#   &quot;locateControl&quot;: false,
#   &quot;searchControl&quot;: true,
#   &quot;basemap&quot;: &quot;OpenStreetMap&quot;,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9fecfa38961fa765f723df0f8fbe93e7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;OpenStreetMap&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9fecfa38961fa765f723df0f8fbe93e7.addTo(map_d1941149f8adbb29a90b660dc1bcef00);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_d1941149f8adbb29a90b660dc1bcef00);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#                 // FeatureGroup is to store editable layers.
#                 var drawnItems_draw_control_37f3bac96882f13988375b2b41c53099 =
#                     new L.featureGroup().addTo(
#                         map_d1941149f8adbb29a90b660dc1bcef00
#                     );
#
#             options.edit.featureGroup = drawnItems_draw_control_37f3bac96882f13988375b2b41c53099;
#             var draw_control_37f3bac96882f13988375b2b41c53099 = new L.Control.Draw(
#                 options
#             ).addTo( map_d1941149f8adbb29a90b660dc1bcef00 );
#             map_d1941149f8adbb29a90b660dc1bcef00.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_37f3bac96882f13988375b2b41c53099.addLayer(layer);
#             });
#             map_d1941149f8adbb29a90b660dc1bcef00.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_37f3bac96882f13988375b2b41c53099.addLayer(e.layer);
#             });
#
#
#
#
#
#             var geocoderOpts_geocoder_b34ff812d7adb6956d254f3bc5d04cf5 = {
#   &quot;collapsed&quot;: true,
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;defaultMarkGeocode&quot;: true,
#   &quot;zoom&quot;: 11,
#   &quot;provider&quot;: &quot;nominatim&quot;,
#   &quot;providerOptions&quot;: {
# },
# };
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_b34ff812d7adb6956d254f3bc5d04cf5 = geocoderOpts_geocoder_b34ff812d7adb6956d254f3bc5d04cf5[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_b34ff812d7adb6956d254f3bc5d04cf5 = L.Control.Geocoder[ geocoderName_geocoder_b34ff812d7adb6956d254f3bc5d04cf5 ](
#                 geocoderOpts_geocoder_b34ff812d7adb6956d254f3bc5d04cf5[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_b34ff812d7adb6956d254f3bc5d04cf5[&quot;geocoder&quot;] = customGeocoder_geocoder_b34ff812d7adb6956d254f3bc5d04cf5;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_b34ff812d7adb6956d254f3bc5d04cf5
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_b34ff812d7adb6956d

# %% [markdown]
# ## Load Sea Surface Temperature
#
# Sea surface temperature (SST) is measured by both MODIS thermal bands and specialized ocean sensors. We'll use MODIS SST from the same collection for consistency.
#
# SST affects:
# - **Marine life distribution**: Many species have temperature preferences
# - **Ocean stratification**: Warm surface water doesn't mix with cold deep water
# - **Hurricane intensity**: Warm water (>26°C) fuels tropical storms
# - **Coral health**: Prolonged high temps cause coral bleaching

# %%
# Load SST from MODIS Ocean Color product
# sst band is in degrees Celsius

# Winter SST
winter_sst = (
    ocean_color
    .filterDate(f"{year}-01-01", f"{year}-02-28")
    .select("sst")  # Sea surface temperature in °C
    .median()
    .clip(gulf_coast)
)

# Summer SST
summer_sst = (
    ocean_color
    .filterDate(f"{year}-07-01", f"{year}-08-31")
    .select("sst")
    .median()
    .clip(gulf_coast)
)

print(f"Loaded SST data for winter and summer {year}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Loaded SST data for winter and summer 2021

# %%
# Thermal palette for SST: blue (cold) to red (hot)
sst_palette = [
    '#313695',  # Dark blue - cold
    '#4575b4',  
    '#74add1',  
    '#abd9e9',  
    '#e0f3f8',  # Light blue
    '#fee090',  # Yellow
    '#fdae61',  # Orange
    '#f46d43',  
    '#d73027',  # Red
    '#a50026',  # Dark red - hot
]

sst_vis = {
    'min': 18,   # 18°C
    'max': 32,   # 32°C
    'palette': sst_palette
}

# Create SST map
m2 = geemap.Map(center=[center_lat, center_lon], zoom=5)

m2.addLayer(summer_sst, sst_vis, f'Sea Surface Temperature Summer {year}')

# Add landmarks
for name, coords in landmarks.items():
    point = ee.Geometry.Point(coords)
    m2.addLayer(point, {'color': 'black'}, name)

m2.add_colorbar(
    sst_vis, 
    label='SST (°C)', 
    layer_name=f'Sea Surface Temperature Summer {year}'
)

m2
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f59a28838cfa58ca5904e9aae357712d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f59a28838cfa58ca5904e9aae357712d&quot; &gt;&lt;/div&gt;
#
#
#
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f59a28838cfa58ca5904e9aae357712d = L.map(
#                 &quot;map_f59a28838cfa58ca5904e9aae357712d&quot;,
#                 {
#                     center: [25.5, -89.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;eeInitialize&quot;: true,
#   &quot;addGoogleMap&quot;: false,
#   &quot;pluginLatlngpopup&quot;: false,
#   &quot;pluginFullscreen&quot;: true,
#   &quot;pluginDraw&quot;: true,
#   &quot;DrawExport&quot;: false,
#   &quot;pluginMinimap&quot;: false,
#   &quot;locateControl&quot;: false,
#   &quot;searchControl&quot;: true,
#   &quot;basemap&quot;: &quot;OpenStreetMap&quot;,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9fecfa38961fa765f723df0f8fbe93e7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;OpenStreetMap&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9fecfa38961fa765f723df0f8fbe93e7.addTo(map_f59a28838cfa58ca5904e9aae357712d);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_f59a28838cfa58ca5904e9aae357712d);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#                 // FeatureGroup is to store editable layers.
#                 var drawnItems_draw_control_63ded9ce545588838461c90647922b2b =
#                     new L.featureGroup().addTo(
#                         map_f59a28838cfa58ca5904e9aae357712d
#                     );
#
#             options.edit.featureGroup = drawnItems_draw_control_63ded9ce545588838461c90647922b2b;
#             var draw_control_63ded9ce545588838461c90647922b2b = new L.Control.Draw(
#                 options
#             ).addTo( map_f59a28838cfa58ca5904e9aae357712d );
#             map_f59a28838cfa58ca5904e9aae357712d.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_63ded9ce545588838461c90647922b2b.addLayer(layer);
#             });
#             map_f59a28838cfa58ca5904e9aae357712d.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_63ded9ce545588838461c90647922b2b.addLayer(e.layer);
#             });
#
#
#
#
#
#             var geocoderOpts_geocoder_c2cf2349ea8a133e33f574b2bf3ab3e1 = {
#   &quot;collapsed&quot;: true,
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;defaultMarkGeocode&quot;: true,
#   &quot;zoom&quot;: 11,
#   &quot;provider&quot;: &quot;nominatim&quot;,
#   &quot;providerOptions&quot;: {
# },
# };
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_c2cf2349ea8a133e33f574b2bf3ab3e1 = geocoderOpts_geocoder_c2cf2349ea8a133e33f574b2bf3ab3e1[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_c2cf2349ea8a133e33f574b2bf3ab3e1 = L.Control.Geocoder[ geocoderName_geocoder_c2cf2349ea8a133e33f574b2bf3ab3e1 ](
#                 geocoderOpts_geocoder_c2cf2349ea8a133e33f574b2bf3ab3e1[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_c2cf2349ea8a133e33f574b2bf3ab3e1[&quot;geocoder&quot;] = customGeocoder_geocoder_c2cf2349ea8a133e33f574b2bf3ab3e1;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_c2cf2349ea8a133e33f574b2bf3ab3e1
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_c2cf2349ea8a133e33

# %% [markdown]
# ## Compare seasonal patterns
#
# Let's compare winter vs. summer chlorophyll to see how productivity changes through the year.
#
# **What to look for:**
# - **Winter**: More mixing → nutrients reach surface → higher offshore productivity
# - **Summer**: Warmer, stratified → Mississippi plume more concentrated along coast

# %%
# Create log-scale chlorophyll for both seasons
winter_chl_log = winter_chl.log10()
summer_chl_log = summer_chl.log10()

# Split map: Winter on left, Summer on right
left_layer = geemap.ee_tile_layer(winter_chl_log, chl_vis, f'Winter {year}')
right_layer = geemap.ee_tile_layer(summer_chl_log, chl_vis, f'Summer {year}')

m3 = geemap.Map(center=[center_lat, center_lon], zoom=5)
m3.split_map(left_layer, right_layer)
m3
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea5333c42fef7cced03e3926bbd2fa16 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/digidem/leaflet-side-by-side@2.0.0/leaflet-side-by-side.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea5333c42fef7cced03e3926bbd2fa16&quot; &gt;&lt;/div&gt;
#
#
#
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea5333c42fef7cced03e3926bbd2fa16 = L.map(
#                 &quot;map_ea5333c42fef7cced03e3926bbd2fa16&quot;,
#                 {
#                     center: [25.5, -89.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;eeInitialize&quot;: true,
#   &quot;addGoogleMap&quot;: false,
#   &quot;pluginLatlngpopup&quot;: false,
#   &quot;pluginFullscreen&quot;: true,
#   &quot;pluginDraw&quot;: true,
#   &quot;DrawExport&quot;: false,
#   &quot;pluginMinimap&quot;: false,
#   &quot;locateControl&quot;: false,
#   &quot;searchControl&quot;: true,
#   &quot;basemap&quot;: &quot;OpenStreetMap&quot;,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9fecfa38961fa765f723df0f8fbe93e7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;OpenStreetMap&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9fecfa38961fa765f723df0f8fbe93e7.addTo(map_ea5333c42fef7cced03e3926bbd2fa16);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_ea5333c42fef7cced03e3926bbd2fa16);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#                 // FeatureGroup is to store editable layers.
#                 var drawnItems_draw_control_99fc6822be2bfd0a0129392b0b9e662f =
#                     new L.featureGroup().addTo(
#                         map_ea5333c42fef7cced03e3926bbd2fa16
#                     );
#
#             options.edit.featureGroup = drawnItems_draw_control_99fc6822be2bfd0a0129392b0b9e662f;
#             var draw_control_99fc6822be2bfd0a0129392b0b9e662f = new L.Control.Draw(
#                 options
#             ).addTo( map_ea5333c42fef7cced03e3926bbd2fa16 );
#             map_ea5333c42fef7cced03e3926bbd2fa16.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_99fc6822be2bfd0a0129392b0b9e662f.addLayer(layer);
#             });
#             map_ea5333c42fef7cced03e3926bbd2fa16.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_99fc6822be2bfd0a0129392b0b9e662f.addLayer(e.layer);
#             });
#
#
#
#
#
#             var geocoderOpts_geocoder_fd8dfb8cdd0d7917c8423a2c5a26d8d5 = {
#   &quot;collapsed&quot;: true,
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;defaultMarkGeocode&quot;: true,
#   &quot;zoom&quot;: 11,
#   &quot;provider&quot;: &quot;nominatim&quot;,
#   &quot;providerOptions&quot;: {
# },
# };
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_fd8dfb8cdd0d7917c8423a2c5a26d8d5 = geocoderOpts_geocoder_fd8dfb8cdd0d7917c8423a2c5a26d8d5[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_fd8dfb8cdd0d7917c8423a2c5a26d8d5 = L.Control.Geocoder[ geocoderName_geocoder_fd8dfb8cdd0d7917c8423a2c5a26d8d5 ](
#                 geocoderOpts_geocoder_fd8dfb8cdd0d7917c8423a2c5a26d8d5[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_fd8dfb8cdd0d7917c8423a2c5a26d8d5[&quot;geocoder&quot;] = customGeocoder_geocoder_fd8dfb8cdd0d7917c8423a2c5a26d8d5;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_fd8dfb8cdd0d7917c8423a2c5a26d8d5
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocode

# %% [markdown]
# ## The Mississippi River plume
#
# The Mississippi River drains 40% of the continental United States. It carries:
# - **Sediment**: Makes water turbid (brown)
# - **Nutrients**: Nitrogen and phosphorus from agricultural runoff
# - **Freshwater**: Less dense than saltwater, so it spreads on top
#
# This nutrient-rich freshwater creates a productivity hotspot - but also a problem. Excess nutrients cause massive algal blooms. When the algae die, bacteria decompose them and consume all the oxygen, creating a **"dead zone"** where fish and other marine life cannot survive.
#
# The Northern Gulf dead zone is the largest in the US, covering 6,000-8,000 square miles in a typical summer.
#
# Let's zoom in on the Mississippi Delta to see this effect.

# %%
# Zoom into Mississippi Delta region
delta_region = ee.Geometry.Rectangle([-92, 27, -87, 30.5])

# Create focused map on the delta
m4 = geemap.Map(center=[28.8, -89.5], zoom=7)

# Clip chlorophyll to delta region
delta_chl_log = summer_chl.clip(delta_region).log10()

m4.addLayer(delta_chl_log, chl_vis, f'Chlorophyll-a Summer {year}')

# Add delta landmark
delta_point = ee.Geometry.Point([-89.5, 29.0])
m4.addLayer(delta_point, {'color': 'red'}, 'Mississippi Delta')

m4.add_colorbar(
    chl_vis, 
    label='Chlorophyll-a (log10 mg/m³)', 
    layer_name=f'Chlorophyll-a Summer {year}'
)

print("Notice the high chlorophyll (yellow/green) spreading from the delta!")
print("This nutrient-rich plume can extend hundreds of kilometers.")
m4
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Notice the high chlorophyll (yellow/green) spreading from the delta!
# This nutrient-rich plume can extend hundreds of kilometers.
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e0001f0bea1a5f8b9affe5fbabae12be {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e0001f0bea1a5f8b9affe5fbabae12be&quot; &gt;&lt;/div&gt;
#
#
#
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e0001f0bea1a5f8b9affe5fbabae12be = L.map(
#                 &quot;map_e0001f0bea1a5f8b9affe5fbabae12be&quot;,
#                 {
#                     center: [28.8, -89.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;eeInitialize&quot;: true,
#   &quot;addGoogleMap&quot;: false,
#   &quot;pluginLatlngpopup&quot;: false,
#   &quot;pluginFullscreen&quot;: true,
#   &quot;pluginDraw&quot;: true,
#   &quot;DrawExport&quot;: false,
#   &quot;pluginMinimap&quot;: false,
#   &quot;locateControl&quot;: false,
#   &quot;searchControl&quot;: true,
#   &quot;basemap&quot;: &quot;OpenStreetMap&quot;,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9fecfa38961fa765f723df0f8fbe93e7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;OpenStreetMap&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9fecfa38961fa765f723df0f8fbe93e7.addTo(map_e0001f0bea1a5f8b9affe5fbabae12be);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_e0001f0bea1a5f8b9affe5fbabae12be);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#                 // FeatureGroup is to store editable layers.
#                 var drawnItems_draw_control_20ec8df37e43a0a356d7f9dccad015cb =
#                     new L.featureGroup().addTo(
#                         map_e0001f0bea1a5f8b9affe5fbabae12be
#                     );
#
#             options.edit.featureGroup = drawnItems_draw_control_20ec8df37e43a0a356d7f9dccad015cb;
#             var draw_control_20ec8df37e43a0a356d7f9dccad015cb = new L.Control.Draw(
#                 options
#             ).addTo( map_e0001f0bea1a5f8b9affe5fbabae12be );
#             map_e0001f0bea1a5f8b9affe5fbabae12be.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_20ec8df37e43a0a356d7f9dccad015cb.addLayer(layer);
#             });
#             map_e0001f0bea1a5f8b9affe5fbabae12be.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_20ec8df37e43a0a356d7f9dccad015cb.addLayer(e.layer);
#             });
#
#
#
#
#
#             var geocoderOpts_geocoder_743773c5df00ce5e6c40bb7cba31f4cd = {
#   &quot;collapsed&quot;: true,
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;defaultMarkGeocode&quot;: true,
#   &quot;zoom&quot;: 11,
#   &quot;provider&quot;: &quot;nominatim&quot;,
#   &quot;providerOptions&quot;: {
# },
# };
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_743773c5df00ce5e6c40bb7cba31f4cd = geocoderOpts_geocoder_743773c5df00ce5e6c40bb7cba31f4cd[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_743773c5df00ce5e6c40bb7cba31f4cd = L.Control.Geocoder[ geocoderName_geocoder_743773c5df00ce5e6c40bb7cba31f4cd ](
#                 geocoderOpts_geocoder_743773c5df00ce5e6c40bb7cba31f4cd[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_743773c5df00ce5e6c40bb7cba31f4cd[&quot;geocoder&quot;] = customGeocoder_geocoder_743773c5df00ce5e6c40bb7cba31f4cd;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_743773c5df00ce5e6c40bb7cba31f4cd
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_743773c5df00ce5e6c

# %% [markdown]
# ## Chlorophyll and SST: Side-by-Side
#
# Is there a relationship between temperature and productivity?
#
# - Cooler waters (from upwelling or river input) often have **higher** nutrients
# - The Loop Current brings warm Caribbean water northward - typically **lower** productivity
# - Coastal areas with river input show both cooler temps and higher chlorophyll

# %%
# Side-by-side: Chlorophyll (left) vs SST (right)
left_layer = geemap.ee_tile_layer(summer_chl_log, chl_vis, f'Chlorophyll-a')
right_layer = geemap.ee_tile_layer(summer_sst, sst_vis, f'SST')

m5 = geemap.Map(center=[center_lat, center_lon], zoom=5)
m5.split_map(left_layer, right_layer)

print("Drag the slider to compare chlorophyll (left) with temperature (right)")
print("Look for: cooler coastal water with high chlorophyll near the Mississippi")
m5
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Drag the slider to compare chlorophyll (left) with temperature (right)
# Look for: cooler coastal water with high chlorophyll near the Mississippi
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_13e85a74ac252709c2cda782ca42fd0a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/digidem/leaflet-side-by-side@2.0.0/leaflet-side-by-side.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_13e85a74ac252709c2cda782ca42fd0a&quot; &gt;&lt;/div&gt;
#
#
#
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_13e85a74ac252709c2cda782ca42fd0a = L.map(
#                 &quot;map_13e85a74ac252709c2cda782ca42fd0a&quot;,
#                 {
#                     center: [25.5, -89.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;eeInitialize&quot;: true,
#   &quot;addGoogleMap&quot;: false,
#   &quot;pluginLatlngpopup&quot;: false,
#   &quot;pluginFullscreen&quot;: true,
#   &quot;pluginDraw&quot;: true,
#   &quot;DrawExport&quot;: false,
#   &quot;pluginMinimap&quot;: false,
#   &quot;locateControl&quot;: false,
#   &quot;searchControl&quot;: true,
#   &quot;basemap&quot;: &quot;OpenStreetMap&quot;,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9fecfa38961fa765f723df0f8fbe93e7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;OpenStreetMap&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9fecfa38961fa765f723df0f8fbe93e7.addTo(map_13e85a74ac252709c2cda782ca42fd0a);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_13e85a74ac252709c2cda782ca42fd0a);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#                 // FeatureGroup is to store editable layers.
#                 var drawnItems_draw_control_9fb59b8f0b38ae3c3f55799ad6fba631 =
#                     new L.featureGroup().addTo(
#                         map_13e85a74ac252709c2cda782ca42fd0a
#                     );
#
#             options.edit.featureGroup = drawnItems_draw_control_9fb59b8f0b38ae3c3f55799ad6fba631;
#             var draw_control_9fb59b8f0b38ae3c3f55799ad6fba631 = new L.Control.Draw(
#                 options
#             ).addTo( map_13e85a74ac252709c2cda782ca42fd0a );
#             map_13e85a74ac252709c2cda782ca42fd0a.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_9fb59b8f0b38ae3c3f55799ad6fba631.addLayer(layer);
#             });
#             map_13e85a74ac252709c2cda782ca42fd0a.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_9fb59b8f0b38ae3c3f55799ad6fba631.addLayer(e.layer);
#             });
#
#
#
#
#
#             var geocoderOpts_geocoder_a3bab39d4ae20bdae1ab615ef42fe260 = {
#   &quot;collapsed&quot;: true,
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;defaultMarkGeocode&quot;: true,
#   &quot;zoom&quot;: 11,
#   &quot;provider&quot;: &quot;nominatim&quot;,
#   &quot;providerOptions&quot;: {
# },
# };
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_a3bab39d4ae20bdae1ab615ef42fe260 = geocoderOpts_geocoder_a3bab39d4ae20bdae1ab615ef42fe260[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_a3bab39d4ae20bdae1ab615ef42fe260 = L.Control.Geocoder[ geocoderName_geocoder_a3bab39d4ae20bdae1ab615ef42fe260 ](
#                 geocoderOpts_geocoder_a3bab39d4ae20bdae1ab615ef42fe260[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_a3bab39d4ae20bdae1ab615ef42fe260[&quot;geocoder&quot;] = customGeocoder_geocoder_a3bab39d4ae20bdae1ab615ef42fe260;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_a3bab39d4ae20bdae1ab615ef42fe260
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocode

# %% [markdown]
# ## What patterns do you notice?
#
# Looking at the maps:
#
# **Chlorophyll patterns:**
# - **Highest productivity** near the Mississippi Delta - the river plume is clearly visible
# - **Coastal enhancement** along Louisiana, Texas, and Florida coasts
# - **Low productivity** in the deep central waters (oligotrophic blue water)
# - **Moderate levels** along the Yucatan coast (upwelling zones)
#
# **Temperature patterns:**
# - **Warmest water** (>30°C) in the central basin - the Loop Current brings Caribbean water
# - **Cooler water** near the coast where river water mixes in
# - **Seasonal variation** is dramatic - winter temps 10-15°C cooler than summer
#
# **The connection:**
# - River plumes are often cooler AND more productive
# - The warm Loop Current is a productivity desert (nutrients are depleted)
# - Eddies spinning off the Loop Current can entrain coastal water and nutrients

# %% [markdown]
# ## Try it yourself
#
# Ideas to explore:
#
# 1. **Harmful algal blooms (red tides)**: Florida's west coast experiences red tides from *Karenia brevis*. Look at chlorophyll during October-November 2017 or 2018 near Tampa Bay.
#
# 2. **El Niño effects**: Compare chlorophyll in a strong El Niño year (2015-2016) vs. a La Niña year (2020-2021). El Niño affects circulation patterns globally.
#
# 3. **Hurricane impacts**: Look at before/after a major hurricane. Storms mix the water column and can trigger plankton blooms. Try Hurricane Katrina (Aug 2005) or Hurricane Ida (Aug 2021).
#
# 4. **Other ocean basins**:
#    - California Current: `ee.Geometry.Rectangle([-130, 30, -115, 45])` - major upwelling zone
#    - Arabian Sea: `ee.Geometry.Rectangle([55, 10, 75, 25])` - monsoon-driven productivity
#    - Southern Ocean: `ee.Geometry.Rectangle([-180, -70, 180, -50])` - phytoplankton blooms visible from space
#
# 5. **Time series**: Create monthly chlorophyll composites for a year to see the seasonal cycle of productivity.
#
# 6. **Coral bleaching**: Look at SST during the 2005 or 2023 bleaching events in the Caribbean. Temps above 29°C for extended periods cause coral stress.
