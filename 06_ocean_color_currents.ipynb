# %% [markdown]
# ## Notebook 6: Ocean Color and Sea Surface Temperature
#
# **The ocean isn't just blue - from space we can see where life thrives.**
#
# When you look at the ocean from a plane, you might notice patches of different colors - turquoise near the coast, deep blue offshore, and sometimes greenish bands. These aren't random variations. They reveal the invisible world of **phytoplankton** - microscopic plants that form the base of the entire ocean food chain.
#
# Satellites measure **ocean color** to estimate chlorophyll concentration, which tells us where phytoplankton are blooming. They also measure **sea surface temperature (SST)**, which affects marine life distribution and ocean circulation.
#
# In this notebook, we'll:
#
# - Visualize chlorophyll-a concentration in the Gulf of Mexico
# - Map sea surface temperature patterns
# - Compare summer vs. winter conditions
# - See how the Mississippi River creates a productivity hotspot
#
# This is how scientists monitor ocean health, track harmful algal blooms, and study the impacts of climate change on marine ecosystems.

# %% [markdown]
# ## Setup
#
# Same initialization as previous notebooks.

# %%
# %pip install -q geemap folium
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import ee
from google.cloud import storage

# Initialize Earth Engine
PROJECT = "eeps-geospatial"
BUCKET = "wustl-eeps-edc"
ee.Initialize(project=PROJECT)

import geemap.foliumap as geemap

print("Ready!")
# Out:
# /opt/conda/lib/python3.10/site-packages/google/api_core/_python_version_support.py:266: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# Ready!

# %% [markdown]
# ## What is ocean color?
#
# **Ocean color** refers to the subtle variations in how the ocean reflects sunlight. Pure open-ocean water appears deep blue because water absorbs red light and scatters blue. But when phytoplankton are present, they add green to the mix.
#
# **Chlorophyll-a** is the key measurement:
# - It's the primary photosynthetic pigment in phytoplankton
# - Higher chlorophyll = more phytoplankton = greener water
# - Measured in **mg/m³** (milligrams per cubic meter)
#
# **Why does this matter?**
# - Phytoplankton produce ~50% of Earth's oxygen through photosynthesis
# - They're the base of the marine food chain (phytoplankton → zooplankton → fish → whales)
# - High productivity areas = good fishing grounds
# - Too much = harmful algal blooms (red tides)
#
# **What drives phytoplankton blooms?**
# - **Nutrients**: Nitrogen, phosphorus from rivers, upwelling, or mixing
# - **Light**: Sunlight for photosynthesis
# - **Temperature**: Affects growth rates and stratification
#
# The Mississippi River is a major nutrient source, making the northern Gulf of Mexico one of the most productive (and problematic) coastal areas in the US.

# %% [markdown]
# ## Define area of interest: Gulf of Mexico
#
# The Gulf of Mexico is a semi-enclosed sea bordered by the US, Mexico, and Cuba. It receives freshwater and nutrients from major rivers including the Mississippi, the largest river system in North America.

# %%
# Gulf of Mexico bounding box
gulf_of_mexico = ee.Geometry.Rectangle([-98, 18, -80, 31])

# Key locations for reference
landmarks = {
    "Mississippi Delta": [-89.5, 29.0],
    "New Orleans": [-90.07, 29.95],
    "Tampa Bay": [-82.5, 27.8],
    "Corpus Christi": [-97.4, 27.8],
    "Cancun": [-86.85, 21.16],
}

# Center point for maps
center_lat = 25.5
center_lon = -89

print("Area of interest: Gulf of Mexico")
print("Key feature: Mississippi River plume brings nutrients into the Gulf")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Area of interest: Gulf of Mexico
# Key feature: Mississippi River plume brings nutrients into the Gulf

# %% [markdown]
# ## Load MODIS Ocean Color data
#
# NASA's MODIS-Aqua satellite has been measuring ocean color since 2002. The **L3SMI** (Level 3 Standard Mapped Image) product provides global daily composites of chlorophyll-a concentration.
#
# We'll compare two seasons:
# - **Winter (Jan-Feb)**: Strong mixing brings nutrients up from deep water
# - **Summer (Jul-Aug)**: Warmer, more stratified - Mississippi plume effects more visible

# %%
# MODIS Ocean Color - Chlorophyll-a concentration
ocean_color = ee.ImageCollection("NASA/OCEANDATA/MODIS-Aqua/L3SMI")

# Use 2023 for recent data
year = 2023

# Winter composite (January-February)
winter_chl = (
    ocean_color
    .filterDate(f"{year}-01-01", f"{year}-02-28")
    .select("chlor_a")  # Chlorophyll-a concentration in mg/m³
    .median()
    .clip(gulf_of_mexico)
)

# Summer composite (July-August)
summer_chl = (
    ocean_color
    .filterDate(f"{year}-07-01", f"{year}-08-31")
    .select("chlor_a")
    .median()
    .clip(gulf_of_mexico)
)

print(f"Loaded chlorophyll-a data for winter and summer {year}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Loaded chlorophyll-a data for winter and summer 2023

# %% [markdown]
# ## Visualize chlorophyll concentration
#
# Chlorophyll-a values vary over orders of magnitude:
# - **< 0.1 mg/m³**: Ultra-oligotrophic (nutrient-poor) open ocean - deep blue
# - **0.1 - 1 mg/m³**: Typical open ocean
# - **1 - 10 mg/m³**: Productive coastal and upwelling areas
# - **> 10 mg/m³**: Very high productivity, potential algal blooms
#
# We use a logarithmic color scale because of this wide range.

# %%
# Chlorophyll palette: purple (low) → blue → green → yellow (high)
chl_palette = [
    '#2c0a4a',  # Dark purple - very low
    '#4a1486',  # Purple
    '#0d47a1',  # Dark blue
    '#1976d2',  # Blue
    '#00acc1',  # Cyan
    '#00897b',  # Teal
    '#43a047',  # Green
    '#7cb342',  # Light green
    '#c0ca33',  # Yellow-green
    '#fdd835',  # Yellow
    '#ff8f00',  # Orange - high
]

# Use log scale for chlorophyll (0.01 to 30 mg/m³)
# Taking log10: log10(0.01) = -2, log10(30) ≈ 1.5
chl_log = summer_chl.log10()

chl_vis = {
    'min': -2,  # 0.01 mg/m³
    'max': 1.5, # ~30 mg/m³
    'palette': chl_palette
}

# Create map
m = geemap.Map(center=[center_lat, center_lon], zoom=5)

# Add chlorophyll layer
m.addLayer(chl_log, chl_vis, f'Chlorophyll-a Summer {year}')

# Add landmarks
for name, coords in landmarks.items():
    point = ee.Geometry.Point(coords)
    m.addLayer(point, {'color': 'white'}, name)

# Add region boundary
m.addLayer(gulf_of_mexico, {'color': 'white'}, 'Gulf of Mexico', False)

m.add_colorbar(
    chl_vis, 
    label='Chlorophyll-a (log10 mg/m³)', 
    layer_name=f'Chlorophyll-a Summer {year}'
)

m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b8128a99c39f1b87415dd17aee79677e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b8128a99c39f1b87415dd17aee79677e&quot; &gt;&lt;/div&gt;
#
#
#
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b8128a99c39f1b87415dd17aee79677e = L.map(
#                 &quot;map_b8128a99c39f1b87415dd17aee79677e&quot;,
#                 {
#                     center: [25.5, -89.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;eeInitialize&quot;: true,
#   &quot;addGoogleMap&quot;: false,
#   &quot;pluginLatlngpopup&quot;: false,
#   &quot;pluginFullscreen&quot;: true,
#   &quot;pluginDraw&quot;: true,
#   &quot;DrawExport&quot;: false,
#   &quot;pluginMinimap&quot;: false,
#   &quot;locateControl&quot;: false,
#   &quot;searchControl&quot;: true,
#   &quot;basemap&quot;: &quot;OpenStreetMap&quot;,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2a9fd1cd20ddcef348dd6084e40fb2bd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;OpenStreetMap&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2a9fd1cd20ddcef348dd6084e40fb2bd.addTo(map_b8128a99c39f1b87415dd17aee79677e);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_b8128a99c39f1b87415dd17aee79677e);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#                 // FeatureGroup is to store editable layers.
#                 var drawnItems_draw_control_30fb169f632d11095923150f399876c4 =
#                     new L.featureGroup().addTo(
#                         map_b8128a99c39f1b87415dd17aee79677e
#                     );
#
#             options.edit.featureGroup = drawnItems_draw_control_30fb169f632d11095923150f399876c4;
#             var draw_control_30fb169f632d11095923150f399876c4 = new L.Control.Draw(
#                 options
#             ).addTo( map_b8128a99c39f1b87415dd17aee79677e );
#             map_b8128a99c39f1b87415dd17aee79677e.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_30fb169f632d11095923150f399876c4.addLayer(layer);
#             });
#             map_b8128a99c39f1b87415dd17aee79677e.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_30fb169f632d11095923150f399876c4.addLayer(e.layer);
#             });
#
#
#
#
#
#             var geocoderOpts_geocoder_fa61ae742b2b68ae2385a6c3f312a03f = {
#   &quot;collapsed&quot;: true,
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;defaultMarkGeocode&quot;: true,
#   &quot;zoom&quot;: 11,
#   &quot;provider&quot;: &quot;nominatim&quot;,
#   &quot;providerOptions&quot;: {
# },
# };
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_fa61ae742b2b68ae2385a6c3f312a03f = geocoderOpts_geocoder_fa61ae742b2b68ae2385a6c3f312a03f[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_fa61ae742b2b68ae2385a6c3f312a03f = L.Control.Geocoder[ geocoderName_geocoder_fa61ae742b2b68ae2385a6c3f312a03f ](
#                 geocoderOpts_geocoder_fa61ae742b2b68ae2385a6c3f312a03f[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_fa61ae742b2b68ae2385a6c3f312a03f[&quot;geocoder&quot;] = customGeocoder_geocoder_fa61ae742b2b68ae2385a6c3f312a03f;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_fa61ae742b2b68ae2385a6c3f312a03f
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_fa61ae742b2b68ae23

# %% [markdown]
# ## Load Sea Surface Temperature
#
# Sea surface temperature (SST) is measured by both MODIS thermal bands and specialized ocean sensors. We'll use MODIS SST from the same collection for consistency.
#
# SST affects:
# - **Marine life distribution**: Many species have temperature preferences
# - **Ocean stratification**: Warm surface water doesn't mix with cold deep water
# - **Hurricane intensity**: Warm water (>26°C) fuels tropical storms
# - **Coral health**: Prolonged high temps cause coral bleaching

# %%
# Load SST from MODIS Ocean Color product
# sst band is in degrees Celsius

# Winter SST
winter_sst = (
    ocean_color
    .filterDate(f"{year}-01-01", f"{year}-02-28")
    .select("sst")  # Sea surface temperature in °C
    .median()
    .clip(gulf_of_mexico)
)

# Summer SST
summer_sst = (
    ocean_color
    .filterDate(f"{year}-07-01", f"{year}-08-31")
    .select("sst")
    .median()
    .clip(gulf_of_mexico)
)

print(f"Loaded SST data for winter and summer {year}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Loaded SST data for winter and summer 2023

# %%
# Thermal palette for SST: blue (cold) to red (hot)
sst_palette = [
    '#313695',  # Dark blue - cold
    '#4575b4',  
    '#74add1',  
    '#abd9e9',  
    '#e0f3f8',  # Light blue
    '#fee090',  # Yellow
    '#fdae61',  # Orange
    '#f46d43',  
    '#d73027',  # Red
    '#a50026',  # Dark red - hot
]

sst_vis = {
    'min': 18,   # 18°C
    'max': 32,   # 32°C
    'palette': sst_palette
}

# Create SST map
m2 = geemap.Map(center=[center_lat, center_lon], zoom=5)

m2.addLayer(summer_sst, sst_vis, f'Sea Surface Temperature Summer {year}')

# Add landmarks
for name, coords in landmarks.items():
    point = ee.Geometry.Point(coords)
    m2.addLayer(point, {'color': 'black'}, name)

m2.add_colorbar(
    sst_vis, 
    label='SST (°C)', 
    layer_name=f'Sea Surface Temperature Summer {year}'
)

m2
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e57e5017d0e04de88fe29840adeb603f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e57e5017d0e04de88fe29840adeb603f&quot; &gt;&lt;/div&gt;
#
#
#
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e57e5017d0e04de88fe29840adeb603f = L.map(
#                 &quot;map_e57e5017d0e04de88fe29840adeb603f&quot;,
#                 {
#                     center: [25.5, -89.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;eeInitialize&quot;: true,
#   &quot;addGoogleMap&quot;: false,
#   &quot;pluginLatlngpopup&quot;: false,
#   &quot;pluginFullscreen&quot;: true,
#   &quot;pluginDraw&quot;: true,
#   &quot;DrawExport&quot;: false,
#   &quot;pluginMinimap&quot;: false,
#   &quot;locateControl&quot;: false,
#   &quot;searchControl&quot;: true,
#   &quot;basemap&quot;: &quot;OpenStreetMap&quot;,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2a9fd1cd20ddcef348dd6084e40fb2bd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;OpenStreetMap&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2a9fd1cd20ddcef348dd6084e40fb2bd.addTo(map_e57e5017d0e04de88fe29840adeb603f);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_e57e5017d0e04de88fe29840adeb603f);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#                 // FeatureGroup is to store editable layers.
#                 var drawnItems_draw_control_640e135090e718a3484fa0bc2a48c154 =
#                     new L.featureGroup().addTo(
#                         map_e57e5017d0e04de88fe29840adeb603f
#                     );
#
#             options.edit.featureGroup = drawnItems_draw_control_640e135090e718a3484fa0bc2a48c154;
#             var draw_control_640e135090e718a3484fa0bc2a48c154 = new L.Control.Draw(
#                 options
#             ).addTo( map_e57e5017d0e04de88fe29840adeb603f );
#             map_e57e5017d0e04de88fe29840adeb603f.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_640e135090e718a3484fa0bc2a48c154.addLayer(layer);
#             });
#             map_e57e5017d0e04de88fe29840adeb603f.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_640e135090e718a3484fa0bc2a48c154.addLayer(e.layer);
#             });
#
#
#
#
#
#             var geocoderOpts_geocoder_7e3545c22ae304098e3a792edcc17aa9 = {
#   &quot;collapsed&quot;: true,
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;defaultMarkGeocode&quot;: true,
#   &quot;zoom&quot;: 11,
#   &quot;provider&quot;: &quot;nominatim&quot;,
#   &quot;providerOptions&quot;: {
# },
# };
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_7e3545c22ae304098e3a792edcc17aa9 = geocoderOpts_geocoder_7e3545c22ae304098e3a792edcc17aa9[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_7e3545c22ae304098e3a792edcc17aa9 = L.Control.Geocoder[ geocoderName_geocoder_7e3545c22ae304098e3a792edcc17aa9 ](
#                 geocoderOpts_geocoder_7e3545c22ae304098e3a792edcc17aa9[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_7e3545c22ae304098e3a792edcc17aa9[&quot;geocoder&quot;] = customGeocoder_geocoder_7e3545c22ae304098e3a792edcc17aa9;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_7e3545c22ae304098e3a792edcc17aa9
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_7e3545c22ae304098e

# %% [markdown]
# ## Compare seasonal patterns
#
# Let's compare winter vs. summer chlorophyll to see how productivity changes through the year.
#
# **What to look for:**
# - **Winter**: More mixing → nutrients reach surface → higher offshore productivity
# - **Summer**: Warmer, stratified → Mississippi plume more concentrated along coast

# %%
# Create log-scale chlorophyll for both seasons
winter_chl_log = winter_chl.log10()
summer_chl_log = summer_chl.log10()

# Split map: Winter on left, Summer on right
left_layer = geemap.ee_tile_layer(winter_chl_log, chl_vis, f'Winter {year}')
right_layer = geemap.ee_tile_layer(summer_chl_log, chl_vis, f'Summer {year}')

m3 = geemap.Map(center=[center_lat, center_lon], zoom=5)
m3.split_map(left_layer, right_layer)
m3
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fc4ab133842bdab29e7c16ec7865ecd4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/digidem/leaflet-side-by-side@2.0.0/leaflet-side-by-side.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fc4ab133842bdab29e7c16ec7865ecd4&quot; &gt;&lt;/div&gt;
#
#
#
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fc4ab133842bdab29e7c16ec7865ecd4 = L.map(
#                 &quot;map_fc4ab133842bdab29e7c16ec7865ecd4&quot;,
#                 {
#                     center: [25.5, -89.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;eeInitialize&quot;: true,
#   &quot;addGoogleMap&quot;: false,
#   &quot;pluginLatlngpopup&quot;: false,
#   &quot;pluginFullscreen&quot;: true,
#   &quot;pluginDraw&quot;: true,
#   &quot;DrawExport&quot;: false,
#   &quot;pluginMinimap&quot;: false,
#   &quot;locateControl&quot;: false,
#   &quot;searchControl&quot;: true,
#   &quot;basemap&quot;: &quot;OpenStreetMap&quot;,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2a9fd1cd20ddcef348dd6084e40fb2bd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;OpenStreetMap&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2a9fd1cd20ddcef348dd6084e40fb2bd.addTo(map_fc4ab133842bdab29e7c16ec7865ecd4);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_fc4ab133842bdab29e7c16ec7865ecd4);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#                 // FeatureGroup is to store editable layers.
#                 var drawnItems_draw_control_7517fbbb8d04ce79397bcdef3a3195d3 =
#                     new L.featureGroup().addTo(
#                         map_fc4ab133842bdab29e7c16ec7865ecd4
#                     );
#
#             options.edit.featureGroup = drawnItems_draw_control_7517fbbb8d04ce79397bcdef3a3195d3;
#             var draw_control_7517fbbb8d04ce79397bcdef3a3195d3 = new L.Control.Draw(
#                 options
#             ).addTo( map_fc4ab133842bdab29e7c16ec7865ecd4 );
#             map_fc4ab133842bdab29e7c16ec7865ecd4.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_7517fbbb8d04ce79397bcdef3a3195d3.addLayer(layer);
#             });
#             map_fc4ab133842bdab29e7c16ec7865ecd4.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_7517fbbb8d04ce79397bcdef3a3195d3.addLayer(e.layer);
#             });
#
#
#
#
#
#             var geocoderOpts_geocoder_9fea0c33ffe3f55ea734a8e6181988ae = {
#   &quot;collapsed&quot;: true,
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;defaultMarkGeocode&quot;: true,
#   &quot;zoom&quot;: 11,
#   &quot;provider&quot;: &quot;nominatim&quot;,
#   &quot;providerOptions&quot;: {
# },
# };
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_9fea0c33ffe3f55ea734a8e6181988ae = geocoderOpts_geocoder_9fea0c33ffe3f55ea734a8e6181988ae[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_9fea0c33ffe3f55ea734a8e6181988ae = L.Control.Geocoder[ geocoderName_geocoder_9fea0c33ffe3f55ea734a8e6181988ae ](
#                 geocoderOpts_geocoder_9fea0c33ffe3f55ea734a8e6181988ae[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_9fea0c33ffe3f55ea734a8e6181988ae[&quot;geocoder&quot;] = customGeocoder_geocoder_9fea0c33ffe3f55ea734a8e6181988ae;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_9fea0c33ffe3f55ea734a8e6181988ae
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocode

# %% [markdown]
# ## The Mississippi River plume
#
# The Mississippi River drains 40% of the continental United States. It carries:
# - **Sediment**: Makes water turbid (brown)
# - **Nutrients**: Nitrogen and phosphorus from agricultural runoff
# - **Freshwater**: Less dense than saltwater, so it spreads on top
#
# This nutrient-rich freshwater creates a productivity hotspot - but also a problem. Excess nutrients cause massive algal blooms. When the algae die, bacteria decompose them and consume all the oxygen, creating a **"dead zone"** where fish and other marine life cannot survive.
#
# The Gulf of Mexico dead zone is the largest in the US, covering 6,000-8,000 square miles in a typical summer.
#
# Let's zoom in on the Mississippi Delta to see this effect.

# %%
# Zoom into Mississippi Delta region
delta_region = ee.Geometry.Rectangle([-92, 27, -87, 30.5])

# Create focused map on the delta
m4 = geemap.Map(center=[28.8, -89.5], zoom=7)

# Clip chlorophyll to delta region
delta_chl_log = summer_chl.clip(delta_region).log10()

m4.addLayer(delta_chl_log, chl_vis, f'Chlorophyll-a Summer {year}')

# Add delta landmark
delta_point = ee.Geometry.Point([-89.5, 29.0])
m4.addLayer(delta_point, {'color': 'red'}, 'Mississippi Delta')

m4.add_colorbar(
    chl_vis, 
    label='Chlorophyll-a (log10 mg/m³)', 
    layer_name=f'Chlorophyll-a Summer {year}'
)

print("Notice the high chlorophyll (yellow/green) spreading from the delta!")
print("This nutrient-rich plume can extend hundreds of kilometers.")
m4
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Notice the high chlorophyll (yellow/green) spreading from the delta!
# This nutrient-rich plume can extend hundreds of kilometers.
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_38e175c8bd8d779cecab3e4a507fb6e5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_38e175c8bd8d779cecab3e4a507fb6e5&quot; &gt;&lt;/div&gt;
#
#
#
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_38e175c8bd8d779cecab3e4a507fb6e5 = L.map(
#                 &quot;map_38e175c8bd8d779cecab3e4a507fb6e5&quot;,
#                 {
#                     center: [28.8, -89.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;eeInitialize&quot;: true,
#   &quot;addGoogleMap&quot;: false,
#   &quot;pluginLatlngpopup&quot;: false,
#   &quot;pluginFullscreen&quot;: true,
#   &quot;pluginDraw&quot;: true,
#   &quot;DrawExport&quot;: false,
#   &quot;pluginMinimap&quot;: false,
#   &quot;locateControl&quot;: false,
#   &quot;searchControl&quot;: true,
#   &quot;basemap&quot;: &quot;OpenStreetMap&quot;,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2a9fd1cd20ddcef348dd6084e40fb2bd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;OpenStreetMap&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2a9fd1cd20ddcef348dd6084e40fb2bd.addTo(map_38e175c8bd8d779cecab3e4a507fb6e5);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_38e175c8bd8d779cecab3e4a507fb6e5);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#                 // FeatureGroup is to store editable layers.
#                 var drawnItems_draw_control_c930cd92def7b1c0c87b6ac64b9f2182 =
#                     new L.featureGroup().addTo(
#                         map_38e175c8bd8d779cecab3e4a507fb6e5
#                     );
#
#             options.edit.featureGroup = drawnItems_draw_control_c930cd92def7b1c0c87b6ac64b9f2182;
#             var draw_control_c930cd92def7b1c0c87b6ac64b9f2182 = new L.Control.Draw(
#                 options
#             ).addTo( map_38e175c8bd8d779cecab3e4a507fb6e5 );
#             map_38e175c8bd8d779cecab3e4a507fb6e5.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_c930cd92def7b1c0c87b6ac64b9f2182.addLayer(layer);
#             });
#             map_38e175c8bd8d779cecab3e4a507fb6e5.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_c930cd92def7b1c0c87b6ac64b9f2182.addLayer(e.layer);
#             });
#
#
#
#
#
#             var geocoderOpts_geocoder_46cb32be00f07088ab3867fdcdd2681c = {
#   &quot;collapsed&quot;: true,
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;defaultMarkGeocode&quot;: true,
#   &quot;zoom&quot;: 11,
#   &quot;provider&quot;: &quot;nominatim&quot;,
#   &quot;providerOptions&quot;: {
# },
# };
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_46cb32be00f07088ab3867fdcdd2681c = geocoderOpts_geocoder_46cb32be00f07088ab3867fdcdd2681c[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_46cb32be00f07088ab3867fdcdd2681c = L.Control.Geocoder[ geocoderName_geocoder_46cb32be00f07088ab3867fdcdd2681c ](
#                 geocoderOpts_geocoder_46cb32be00f07088ab3867fdcdd2681c[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_46cb32be00f07088ab3867fdcdd2681c[&quot;geocoder&quot;] = customGeocoder_geocoder_46cb32be00f07088ab3867fdcdd2681c;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_46cb32be00f07088ab3867fdcdd2681c
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_46cb32be00f07088ab

# %% [markdown]
# ## Chlorophyll and SST: Side-by-Side
#
# Is there a relationship between temperature and productivity?
#
# - Cooler waters (from upwelling or river input) often have **higher** nutrients
# - The Loop Current brings warm Caribbean water into the Gulf - typically **lower** productivity
# - Coastal areas with river input show both cooler temps and higher chlorophyll

# %%
# Side-by-side: Chlorophyll (left) vs SST (right)
left_layer = geemap.ee_tile_layer(summer_chl_log, chl_vis, f'Chlorophyll-a')
right_layer = geemap.ee_tile_layer(summer_sst, sst_vis, f'SST')

m5 = geemap.Map(center=[center_lat, center_lon], zoom=5)
m5.split_map(left_layer, right_layer)

print("Drag the slider to compare chlorophyll (left) with temperature (right)")
print("Look for: cooler coastal water with high chlorophyll near the Mississippi")
m5
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Drag the slider to compare chlorophyll (left) with temperature (right)
# Look for: cooler coastal water with high chlorophyll near the Mississippi
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e658106a449e87cafaa6b685c9fed9b8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/digidem/leaflet-side-by-side@2.0.0/leaflet-side-by-side.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e658106a449e87cafaa6b685c9fed9b8&quot; &gt;&lt;/div&gt;
#
#
#
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e658106a449e87cafaa6b685c9fed9b8 = L.map(
#                 &quot;map_e658106a449e87cafaa6b685c9fed9b8&quot;,
#                 {
#                     center: [25.5, -89.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;eeInitialize&quot;: true,
#   &quot;addGoogleMap&quot;: false,
#   &quot;pluginLatlngpopup&quot;: false,
#   &quot;pluginFullscreen&quot;: true,
#   &quot;pluginDraw&quot;: true,
#   &quot;DrawExport&quot;: false,
#   &quot;pluginMinimap&quot;: false,
#   &quot;locateControl&quot;: false,
#   &quot;searchControl&quot;: true,
#   &quot;basemap&quot;: &quot;OpenStreetMap&quot;,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2a9fd1cd20ddcef348dd6084e40fb2bd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;OpenStreetMap&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2a9fd1cd20ddcef348dd6084e40fb2bd.addTo(map_e658106a449e87cafaa6b685c9fed9b8);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_e658106a449e87cafaa6b685c9fed9b8);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#                 // FeatureGroup is to store editable layers.
#                 var drawnItems_draw_control_7fecf9b2a37feeb7ef91b639769632bf =
#                     new L.featureGroup().addTo(
#                         map_e658106a449e87cafaa6b685c9fed9b8
#                     );
#
#             options.edit.featureGroup = drawnItems_draw_control_7fecf9b2a37feeb7ef91b639769632bf;
#             var draw_control_7fecf9b2a37feeb7ef91b639769632bf = new L.Control.Draw(
#                 options
#             ).addTo( map_e658106a449e87cafaa6b685c9fed9b8 );
#             map_e658106a449e87cafaa6b685c9fed9b8.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_7fecf9b2a37feeb7ef91b639769632bf.addLayer(layer);
#             });
#             map_e658106a449e87cafaa6b685c9fed9b8.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_7fecf9b2a37feeb7ef91b639769632bf.addLayer(e.layer);
#             });
#
#
#
#
#
#             var geocoderOpts_geocoder_6e0877a10d4060ab9536fe9e3015040c = {
#   &quot;collapsed&quot;: true,
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;defaultMarkGeocode&quot;: true,
#   &quot;zoom&quot;: 11,
#   &quot;provider&quot;: &quot;nominatim&quot;,
#   &quot;providerOptions&quot;: {
# },
# };
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_6e0877a10d4060ab9536fe9e3015040c = geocoderOpts_geocoder_6e0877a10d4060ab9536fe9e3015040c[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_6e0877a10d4060ab9536fe9e3015040c = L.Control.Geocoder[ geocoderName_geocoder_6e0877a10d4060ab9536fe9e3015040c ](
#                 geocoderOpts_geocoder_6e0877a10d4060ab9536fe9e3015040c[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_6e0877a10d4060ab9536fe9e3015040c[&quot;geocoder&quot;] = customGeocoder_geocoder_6e0877a10d4060ab9536fe9e3015040c;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_6e0877a10d4060ab9536fe9e3015040c
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocode

# %% [markdown]
# ## What patterns do you notice?
#
# Looking at the maps:
#
# **Chlorophyll patterns:**
# - **Highest productivity** near the Mississippi Delta - the river plume is clearly visible
# - **Coastal enhancement** along Louisiana, Texas, and Florida coasts
# - **Low productivity** in the deep central Gulf (oligotrophic blue water)
# - **Moderate levels** along the Yucatan coast (upwelling zones)
#
# **Temperature patterns:**
# - **Warmest water** (>30°C) in the central Gulf - the Loop Current brings Caribbean water
# - **Cooler water** near the coast where river water mixes in
# - **Seasonal variation** is dramatic - winter temps 10-15°C cooler than summer
#
# **The connection:**
# - River plumes are often cooler AND more productive
# - The warm Loop Current is a productivity desert (nutrients are depleted)
# - Eddies spinning off the Loop Current can entrain coastal water and nutrients

# %% [markdown]
# ## Try it yourself
#
# Ideas to explore:
#
# 1. **Harmful algal blooms (red tides)**: Florida's west coast experiences red tides from *Karenia brevis*. Look at chlorophyll during October-November 2017 or 2018 near Tampa Bay.
#
# 2. **El Niño effects**: Compare chlorophyll in a strong El Niño year (2015-2016) vs. a La Niña year (2020-2021). El Niño affects circulation patterns globally.
#
# 3. **Hurricane impacts**: Look at before/after a major hurricane. Storms mix the water column and can trigger plankton blooms. Try Hurricane Katrina (Aug 2005) or Hurricane Ida (Aug 2021).
#
# 4. **Other ocean basins**:
#    - California Current: `ee.Geometry.Rectangle([-130, 30, -115, 45])` - major upwelling zone
#    - Arabian Sea: `ee.Geometry.Rectangle([55, 10, 75, 25])` - monsoon-driven productivity
#    - Southern Ocean: `ee.Geometry.Rectangle([-180, -70, 180, -50])` - phytoplankton blooms visible from space
#
# 5. **Time series**: Create monthly chlorophyll composites for a year to see the seasonal cycle of productivity.
#
# 6. **Coral bleaching**: Look at SST during the 2005 or 2023 bleaching events in the Caribbean. Temps above 29°C for extended periods cause coral stress.
