# %% [markdown]
# ## Notebook 7: Mapping Soil Properties
#
# **Why do some fields drain well and others stay muddy? The answer is underground.**
#
# Walk across a farm after a rain and you'll notice some areas dry out quickly while others stay waterlogged for days. Drive across Missouri and the soil color changes from brown to red to gray. These differences aren't random - they reflect the underlying **soil properties** that took thousands of years to form.
#
# Soil properties control:
# - **What crops grow best** - corn loves well-drained loam; rice needs heavy clay
# - **How water moves** - sandy soil drains fast; clay holds water
# - **Nutrient availability** - pH affects which nutrients plants can access
# - **Carbon storage** - organic-rich soils store more carbon
#
# In this notebook, we'll:
#
# - Map clay content, organic carbon, and pH across Missouri
# - See how soil texture varies from the Ozarks to the river bottoms
# - Compare soil properties to actual cropland patterns
#
# This data comes from **SSURGO** (Soil Survey Geographic Database) and **OpenLandMap** - decades of soil scientists digging pits and analyzing samples, now available from space.

# %% [markdown]
# ## Setup
#
# Same initialization as previous notebooks.

# %%
# %pip install -q geemap folium
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import ee

# Initialize Earth Engine
PROJECT = "eeps-geospatial"
BUCKET = "wustl-eeps-edc"
ee.Initialize(project=PROJECT)

import geemap.foliumap as geemap

print("Ready!")
# Out:
# Ready!

# %% [markdown]
# ## What is SSURGO?
#
# **SSURGO** (Soil Survey Geographic Database) is the most detailed soil mapping available for the United States. It's maintained by the USDA Natural Resources Conservation Service (NRCS).
#
# **How was it made?**
# - Soil scientists walked the land, dug pits, and classified soils
# - Each soil type ("map unit") has measured properties: texture, drainage, chemistry
# - Decades of work, now digitized and available in GIS format
#
# **OpenLandMap** takes SSURGO and similar datasets worldwide to create global soil property maps at ~250m resolution. We'll use these gridded products today.
#
# **Key soil properties:**
#
# | Property | What it tells you | Agricultural importance |
# |----------|-------------------|------------------------|
# | **Clay content** | How fine the particles are | High clay = slow drainage, hard to till |
# | **Sand content** | How coarse the particles are | High sand = fast drainage, low nutrients |
# | **Organic carbon** | Decomposed plant material | More = better fertility, water holding |
# | **pH** | Acidity/alkalinity | Affects nutrient availability |
# | **Texture class** | Overall particle size mix | Loam is ideal for most crops |

# %% [markdown]
# ## Define area of interest: Missouri
#
# Missouri has diverse soils because of its varied geology:
# - **Glaciated plains** in the north - deep, fertile, loess-derived soils
# - **Ozark Highlands** in the south - thin, rocky, acidic soils
# - **Alluvial bottomlands** along rivers - heavy clay, poorly drained
# - **Mississippi River floodplain** (Bootheel) - rich but flood-prone

# %%
# Get Missouri boundary from TIGER
states = ee.FeatureCollection("TIGER/2018/States")
missouri = states.filter(ee.Filter.eq("NAME", "Missouri"))
mo_geometry = missouri.geometry()

# Center point for maps
center_lat = 38.5
center_lon = -92.5

# Key landmarks for comparison
landmarks = {
    "Northern Plains (Macon Co)": [-92.5, 39.8],
    "Ozarks (Shannon Co)": [-91.4, 37.1],
    "Bootheel (Dunklin Co)": [-90.1, 36.2],
    "Missouri River Bottom": [-92.8, 38.7],
}

print("Area of interest: Missouri")
print("We'll compare soil properties across different regions.")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Area of interest: Missouri
# We'll compare soil properties across different regions.

# %% [markdown]
# ## Load soil property datasets
#
# We'll load three key properties from OpenLandMap:
# 1. **Clay content** (%) - affects drainage and workability
# 2. **Organic carbon** (g/kg) - indicates fertility and carbon storage
# 3. **Soil pH** - controls nutrient availability
#
# Each dataset has multiple depth layers (0, 10, 30, 60, 100, 200 cm). We'll use the surface layer (0 cm) since it's most relevant for agriculture.

# %%
# Load OpenLandMap soil datasets - surface layer (b0 = 0cm depth)

clay = ee.Image("OpenLandMap/SOL/SOL_CLAY-WFRACTION_USDA-3A1A1A_M/v02").select("b0")
organic_carbon = ee.Image("OpenLandMap/SOL/SOL_ORGANIC-CARBON_USDA-6A1C_M/v02").select("b0")  # g/kg × 10
ph = ee.Image("OpenLandMap/SOL/SOL_PH-H2O_USDA-4C1A2A_M/v02").select("b0")  # pH × 10
sand = ee.Image("OpenLandMap/SOL/SOL_SAND-WFRACTION_USDA-3A1A1A_M/v02").select("b0")

# Clip to Missouri
clay_mo = clay.clip(mo_geometry)
oc_mo = organic_carbon.clip(mo_geometry)
ph_mo = ph.clip(mo_geometry)
sand_mo = sand.clip(mo_geometry)

print("Loaded soil property data")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Loaded soil property data

# %% [markdown]
# ## Map 1: Clay content
#
# Clay content is one of the most important soil properties for agriculture:
#
# - **High clay (>35%)**: Heavy soils that hold water, hard to work when wet, crack when dry
# - **Medium clay (20-35%)**: Good balance of drainage and water retention
# - **Low clay (<20%)**: Sandy/silty soils that drain quickly but may need irrigation
#
# In Missouri, expect to see:
# - High clay in river bottoms and the Bootheel
# - Lower clay in the Ozarks (thin, rocky soils)

# %%
# Clay visualization - brown palette
clay_palette = ['#ffffd4', '#fed98e', '#d95f0e', '#993404']

clay_vis = {
    'min': 10,
    'max': 45,
    'palette': clay_palette
}

m1 = geemap.Map(center=[center_lat, center_lon], zoom=7)
m1.addLayer(clay_mo, clay_vis, 'Clay Content (%)')
m1.addLayer(mo_geometry, {'color': 'black'}, 'Missouri', False)
m1.add_colorbar(clay_vis, label='Clay Content (%)', layer_name='Clay Content (%)')
m1
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d18cff3375e53dc4ed2864b77e7fbc78 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d18cff3375e53dc4ed2864b77e7fbc78&quot; &gt;&lt;/div&gt;
#
#
#
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d18cff3375e53dc4ed2864b77e7fbc78 = L.map(
#                 &quot;map_d18cff3375e53dc4ed2864b77e7fbc78&quot;,
#                 {
#                     center: [38.5, -92.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;eeInitialize&quot;: true,
#   &quot;addGoogleMap&quot;: false,
#   &quot;pluginLatlngpopup&quot;: false,
#   &quot;pluginFullscreen&quot;: true,
#   &quot;pluginDraw&quot;: true,
#   &quot;DrawExport&quot;: false,
#   &quot;pluginMinimap&quot;: false,
#   &quot;locateControl&quot;: false,
#   &quot;searchControl&quot;: true,
#   &quot;basemap&quot;: &quot;OpenStreetMap&quot;,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aace1e70da1607973ae7287223edee6c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;OpenStreetMap&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aace1e70da1607973ae7287223edee6c.addTo(map_d18cff3375e53dc4ed2864b77e7fbc78);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_d18cff3375e53dc4ed2864b77e7fbc78);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#                 // FeatureGroup is to store editable layers.
#                 var drawnItems_draw_control_5acfd25e079302e67c62723255ec7060 =
#                     new L.featureGroup().addTo(
#                         map_d18cff3375e53dc4ed2864b77e7fbc78
#                     );
#
#             options.edit.featureGroup = drawnItems_draw_control_5acfd25e079302e67c62723255ec7060;
#             var draw_control_5acfd25e079302e67c62723255ec7060 = new L.Control.Draw(
#                 options
#             ).addTo( map_d18cff3375e53dc4ed2864b77e7fbc78 );
#             map_d18cff3375e53dc4ed2864b77e7fbc78.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_5acfd25e079302e67c62723255ec7060.addLayer(layer);
#             });
#             map_d18cff3375e53dc4ed2864b77e7fbc78.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_5acfd25e079302e67c62723255ec7060.addLayer(e.layer);
#             });
#
#
#
#
#
#             var geocoderOpts_geocoder_b2a9be9d567d64410e9914401b9237f2 = {
#   &quot;collapsed&quot;: true,
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;defaultMarkGeocode&quot;: true,
#   &quot;zoom&quot;: 11,
#   &quot;provider&quot;: &quot;nominatim&quot;,
#   &quot;providerOptions&quot;: {
# },
# };
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_b2a9be9d567d64410e9914401b9237f2 = geocoderOpts_geocoder_b2a9be9d567d64410e9914401b9237f2[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_b2a9be9d567d64410e9914401b9237f2 = L.Control.Geocoder[ geocoderName_geocoder_b2a9be9d567d64410e9914401b9237f2 ](
#                 geocoderOpts_geocoder_b2a9be9d567d64410e9914401b9237f2[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_b2a9be9d567d64410e9914401b9237f2[&quot;geocoder&quot;] = customGeocoder_geocoder_b2a9be9d567d64410e9914401b9237f2;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_b2a9be9d567d64410e9914401b9237f2
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_b2a9be9d567d64410e

# %% [markdown]
# ## Map 2: Soil organic carbon
#
# Organic carbon is decomposed plant and animal material - the "dark" in dark soil. It's critical for:
#
# - **Fertility**: Organic matter releases nutrients as it decomposes
# - **Water holding**: Acts like a sponge to retain moisture
# - **Soil structure**: Helps soil particles clump together
# - **Climate**: Soils store more carbon than the atmosphere!
#
# The data is stored as g/kg × 10, so values of 20 = 2.0 g/kg organic carbon.

# %%
# Organic carbon palette - darker = more carbon
oc_palette = ['#f7f7f7', '#bdbdbd', '#636363', '#252525']

oc_vis = {
    'min': 0,
    'max': 20,  # 2.0 g/kg actual
    'palette': oc_palette
}

m2 = geemap.Map(center=[center_lat, center_lon], zoom=7)
m2.addLayer(oc_mo, oc_vis, 'Organic Carbon')
m2.add_colorbar(oc_vis, label='Organic Carbon (g/kg × 10)', layer_name='Organic Carbon')
m2
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_562078ffd4103c29755cdf92262cff5e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_562078ffd4103c29755cdf92262cff5e&quot; &gt;&lt;/div&gt;
#
#
#
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_562078ffd4103c29755cdf92262cff5e = L.map(
#                 &quot;map_562078ffd4103c29755cdf92262cff5e&quot;,
#                 {
#                     center: [38.5, -92.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;eeInitialize&quot;: true,
#   &quot;addGoogleMap&quot;: false,
#   &quot;pluginLatlngpopup&quot;: false,
#   &quot;pluginFullscreen&quot;: true,
#   &quot;pluginDraw&quot;: true,
#   &quot;DrawExport&quot;: false,
#   &quot;pluginMinimap&quot;: false,
#   &quot;locateControl&quot;: false,
#   &quot;searchControl&quot;: true,
#   &quot;basemap&quot;: &quot;OpenStreetMap&quot;,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aace1e70da1607973ae7287223edee6c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;OpenStreetMap&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aace1e70da1607973ae7287223edee6c.addTo(map_562078ffd4103c29755cdf92262cff5e);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_562078ffd4103c29755cdf92262cff5e);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#                 // FeatureGroup is to store editable layers.
#                 var drawnItems_draw_control_b0d9368cea84f365ef75ccfa29a72d7a =
#                     new L.featureGroup().addTo(
#                         map_562078ffd4103c29755cdf92262cff5e
#                     );
#
#             options.edit.featureGroup = drawnItems_draw_control_b0d9368cea84f365ef75ccfa29a72d7a;
#             var draw_control_b0d9368cea84f365ef75ccfa29a72d7a = new L.Control.Draw(
#                 options
#             ).addTo( map_562078ffd4103c29755cdf92262cff5e );
#             map_562078ffd4103c29755cdf92262cff5e.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_b0d9368cea84f365ef75ccfa29a72d7a.addLayer(layer);
#             });
#             map_562078ffd4103c29755cdf92262cff5e.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_b0d9368cea84f365ef75ccfa29a72d7a.addLayer(e.layer);
#             });
#
#
#
#
#
#             var geocoderOpts_geocoder_52840b1cddfe2da4cb81bc4e5bfd0d85 = {
#   &quot;collapsed&quot;: true,
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;defaultMarkGeocode&quot;: true,
#   &quot;zoom&quot;: 11,
#   &quot;provider&quot;: &quot;nominatim&quot;,
#   &quot;providerOptions&quot;: {
# },
# };
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_52840b1cddfe2da4cb81bc4e5bfd0d85 = geocoderOpts_geocoder_52840b1cddfe2da4cb81bc4e5bfd0d85[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_52840b1cddfe2da4cb81bc4e5bfd0d85 = L.Control.Geocoder[ geocoderName_geocoder_52840b1cddfe2da4cb81bc4e5bfd0d85 ](
#                 geocoderOpts_geocoder_52840b1cddfe2da4cb81bc4e5bfd0d85[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_52840b1cddfe2da4cb81bc4e5bfd0d85[&quot;geocoder&quot;] = customGeocoder_geocoder_52840b1cddfe2da4cb81bc4e5bfd0d85;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_52840b1cddfe2da4cb81bc4e5bfd0d85
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_52840b1cddfe2da4cb

# %% [markdown]
# ## Map 3: Soil pH
#
# Soil pH determines which nutrients plants can access:
#
# - **Acidic (pH < 6)**: Common in high-rainfall areas; limits phosphorus, calcium availability
# - **Neutral (pH 6-7.5)**: Ideal for most crops; nutrients most available
# - **Alkaline (pH > 7.5)**: Common in dry areas; can limit iron, zinc availability
#
# Most Missouri soils are slightly acidic (pH 5-6.5) due to moderate rainfall leaching calcium from the soil.

# %%
ph_actual = ph_mo.divide(10)

# pH palette - red (acidic) to green (alkaline)
ph_palette = ['#d73027', '#fc8d59', '#d9ef8b', '#91cf60', '#1a9850']

ph_vis = {
    'min': 4.5,
    'max': 8.0,
    'palette': ph_palette
}

m3 = geemap.Map(center=[center_lat, center_lon], zoom=7)
m3.addLayer(ph_actual, ph_vis, 'Soil pH')
m3.add_colorbar(ph_vis, label='Soil pH', layer_name='Soil pH')
m3
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4621e74ee80435bbcbc108af73e53713 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4621e74ee80435bbcbc108af73e53713&quot; &gt;&lt;/div&gt;
#
#
#
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4621e74ee80435bbcbc108af73e53713 = L.map(
#                 &quot;map_4621e74ee80435bbcbc108af73e53713&quot;,
#                 {
#                     center: [38.5, -92.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;eeInitialize&quot;: true,
#   &quot;addGoogleMap&quot;: false,
#   &quot;pluginLatlngpopup&quot;: false,
#   &quot;pluginFullscreen&quot;: true,
#   &quot;pluginDraw&quot;: true,
#   &quot;DrawExport&quot;: false,
#   &quot;pluginMinimap&quot;: false,
#   &quot;locateControl&quot;: false,
#   &quot;searchControl&quot;: true,
#   &quot;basemap&quot;: &quot;OpenStreetMap&quot;,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aace1e70da1607973ae7287223edee6c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;OpenStreetMap&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aace1e70da1607973ae7287223edee6c.addTo(map_4621e74ee80435bbcbc108af73e53713);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_4621e74ee80435bbcbc108af73e53713);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#                 // FeatureGroup is to store editable layers.
#                 var drawnItems_draw_control_d521c574165a02453acb84e91f34a0a2 =
#                     new L.featureGroup().addTo(
#                         map_4621e74ee80435bbcbc108af73e53713
#                     );
#
#             options.edit.featureGroup = drawnItems_draw_control_d521c574165a02453acb84e91f34a0a2;
#             var draw_control_d521c574165a02453acb84e91f34a0a2 = new L.Control.Draw(
#                 options
#             ).addTo( map_4621e74ee80435bbcbc108af73e53713 );
#             map_4621e74ee80435bbcbc108af73e53713.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_d521c574165a02453acb84e91f34a0a2.addLayer(layer);
#             });
#             map_4621e74ee80435bbcbc108af73e53713.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_d521c574165a02453acb84e91f34a0a2.addLayer(e.layer);
#             });
#
#
#
#
#
#             var geocoderOpts_geocoder_18417278392e59dd2b6c862b12757b66 = {
#   &quot;collapsed&quot;: true,
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;defaultMarkGeocode&quot;: true,
#   &quot;zoom&quot;: 11,
#   &quot;provider&quot;: &quot;nominatim&quot;,
#   &quot;providerOptions&quot;: {
# },
# };
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_18417278392e59dd2b6c862b12757b66 = geocoderOpts_geocoder_18417278392e59dd2b6c862b12757b66[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_18417278392e59dd2b6c862b12757b66 = L.Control.Geocoder[ geocoderName_geocoder_18417278392e59dd2b6c862b12757b66 ](
#                 geocoderOpts_geocoder_18417278392e59dd2b6c862b12757b66[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_18417278392e59dd2b6c862b12757b66[&quot;geocoder&quot;] = customGeocoder_geocoder_18417278392e59dd2b6c862b12757b66;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_18417278392e59dd2b6c862b12757b66
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_18417278392e59dd2b

# %% [markdown]
# ## Compare soil properties to land use
#
# Let's see how soil properties relate to actual farming patterns. We'll overlay clay content with the USDA Cropland Data Layer (CDL), which maps crop types from satellite imagery.
#
# **Expected patterns:**
# - High-clay river bottoms → soybeans, rice (in Bootheel)
# - Well-drained loamy soils → corn, soybeans in rotation
# - Thin Ozark soils → pasture and forest, not row crops

# %%
# Load USDA Cropland Data Layer
cdl = ee.ImageCollection("USDA/NASS/CDL")

# Get most recent year
cdl_2023 = cdl.filter(ee.Filter.eq('system:index', '2023')).first().select('cropland')
cdl_mo = cdl_2023.clip(mo_geometry)

# CDL class values for reference:
# 1 = Corn, 5 = Soybeans, 24 = Winter Wheat, 36 = Alfalfa
# 37 = Pasture, 63 = Forest, 111 = Water, 121-124 = Developed

print("Loaded 2023 Cropland Data Layer")
print("\nCommon crop codes:")
print("  1 = Corn")
print("  5 = Soybeans")
print("  24 = Winter Wheat")
print("  37 = Pasture/Hay")
print("  63 = Forest")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Loaded 2023 Cropland Data Layer
#
# Common crop codes:
#   1 = Corn
#   5 = Soybeans
#   24 = Winter Wheat
#   37 = Pasture/Hay
#   63 = Forest

# %%
left_layer = geemap.ee_tile_layer(clay_mo, clay_vis, 'Clay Content')
right_layer = geemap.ee_tile_layer(cdl_mo, {}, 'Cropland 2023')

m4 = geemap.Map(center=[center_lat, center_lon], zoom=7)
m4.split_map(left_layer, right_layer)
m4
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_db84a9b3d8287b59a7a19aa7c0888cf0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/digidem/leaflet-side-by-side@2.0.0/leaflet-side-by-side.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_db84a9b3d8287b59a7a19aa7c0888cf0&quot; &gt;&lt;/div&gt;
#
#
#
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_db84a9b3d8287b59a7a19aa7c0888cf0 = L.map(
#                 &quot;map_db84a9b3d8287b59a7a19aa7c0888cf0&quot;,
#                 {
#                     center: [38.5, -92.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;eeInitialize&quot;: true,
#   &quot;addGoogleMap&quot;: false,
#   &quot;pluginLatlngpopup&quot;: false,
#   &quot;pluginFullscreen&quot;: true,
#   &quot;pluginDraw&quot;: true,
#   &quot;DrawExport&quot;: false,
#   &quot;pluginMinimap&quot;: false,
#   &quot;locateControl&quot;: false,
#   &quot;searchControl&quot;: true,
#   &quot;basemap&quot;: &quot;OpenStreetMap&quot;,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aace1e70da1607973ae7287223edee6c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;OpenStreetMap&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aace1e70da1607973ae7287223edee6c.addTo(map_db84a9b3d8287b59a7a19aa7c0888cf0);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_db84a9b3d8287b59a7a19aa7c0888cf0);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#                 // FeatureGroup is to store editable layers.
#                 var drawnItems_draw_control_9c038b0e0f3b75bbf8d69f3b7c592dd4 =
#                     new L.featureGroup().addTo(
#                         map_db84a9b3d8287b59a7a19aa7c0888cf0
#                     );
#
#             options.edit.featureGroup = drawnItems_draw_control_9c038b0e0f3b75bbf8d69f3b7c592dd4;
#             var draw_control_9c038b0e0f3b75bbf8d69f3b7c592dd4 = new L.Control.Draw(
#                 options
#             ).addTo( map_db84a9b3d8287b59a7a19aa7c0888cf0 );
#             map_db84a9b3d8287b59a7a19aa7c0888cf0.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_9c038b0e0f3b75bbf8d69f3b7c592dd4.addLayer(layer);
#             });
#             map_db84a9b3d8287b59a7a19aa7c0888cf0.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_9c038b0e0f3b75bbf8d69f3b7c592dd4.addLayer(e.layer);
#             });
#
#
#
#
#
#             var geocoderOpts_geocoder_4a6049928f3cfcca1a60d7449ca420d3 = {
#   &quot;collapsed&quot;: true,
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;defaultMarkGeocode&quot;: true,
#   &quot;zoom&quot;: 11,
#   &quot;provider&quot;: &quot;nominatim&quot;,
#   &quot;providerOptions&quot;: {
# },
# };
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_4a6049928f3cfcca1a60d7449ca420d3 = geocoderOpts_geocoder_4a6049928f3cfcca1a60d7449ca420d3[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_4a6049928f3cfcca1a60d7449ca420d3 = L.Control.Geocoder[ geocoderName_geocoder_4a6049928f3cfcca1a60d7449ca420d3 ](
#                 geocoderOpts_geocoder_4a6049928f3cfcca1a60d7449ca420d3[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_4a6049928f3cfcca1a60d7449ca420d3[&quot;geocoder&quot;] = customGeocoder_geocoder_4a6049928f3cfcca1a60d7449ca420d3;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_4a6049928f3cfcca1a60d7449ca420d3
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocode

# %% [markdown]
# ## Zoom in: County-level patterns
#
# Let's look at Boone County (home of Columbia and Mizzou) to see field-scale soil patterns. This county has diverse soils from river bottoms to upland ridges.

# %%
counties = ee.FeatureCollection("TIGER/2018/Counties")
boone = counties.filter(
    ee.Filter.And(
        ee.Filter.eq("STATEFP", "29"),
        ee.Filter.eq("NAME", "Boone")
    )
)
boone_geom = boone.geometry()

clay_boone = clay.clip(boone_geom)

m5 = geemap.Map(center=[38.95, -92.33], zoom=10)
m5.addLayer(clay_boone, clay_vis, 'Clay Content (%)')
m5.addLayer(boone_geom, {'color': 'black'}, 'Boone County', False)
m5.add_colorbar(clay_vis, label='Clay Content (%)', layer_name='Clay Content (%)')
m5
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e79d8a330ef0e68e7262642a8ea21a8c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e79d8a330ef0e68e7262642a8ea21a8c&quot; &gt;&lt;/div&gt;
#
#
#
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e79d8a330ef0e68e7262642a8ea21a8c = L.map(
#                 &quot;map_e79d8a330ef0e68e7262642a8ea21a8c&quot;,
#                 {
#                     center: [38.95, -92.33],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;eeInitialize&quot;: true,
#   &quot;addGoogleMap&quot;: false,
#   &quot;pluginLatlngpopup&quot;: false,
#   &quot;pluginFullscreen&quot;: true,
#   &quot;pluginDraw&quot;: true,
#   &quot;DrawExport&quot;: false,
#   &quot;pluginMinimap&quot;: false,
#   &quot;locateControl&quot;: false,
#   &quot;searchControl&quot;: true,
#   &quot;basemap&quot;: &quot;OpenStreetMap&quot;,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aace1e70da1607973ae7287223edee6c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;OpenStreetMap&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aace1e70da1607973ae7287223edee6c.addTo(map_e79d8a330ef0e68e7262642a8ea21a8c);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_e79d8a330ef0e68e7262642a8ea21a8c);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#                 // FeatureGroup is to store editable layers.
#                 var drawnItems_draw_control_7b393f38a8585bbe20782664bb86c01f =
#                     new L.featureGroup().addTo(
#                         map_e79d8a330ef0e68e7262642a8ea21a8c
#                     );
#
#             options.edit.featureGroup = drawnItems_draw_control_7b393f38a8585bbe20782664bb86c01f;
#             var draw_control_7b393f38a8585bbe20782664bb86c01f = new L.Control.Draw(
#                 options
#             ).addTo( map_e79d8a330ef0e68e7262642a8ea21a8c );
#             map_e79d8a330ef0e68e7262642a8ea21a8c.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_7b393f38a8585bbe20782664bb86c01f.addLayer(layer);
#             });
#             map_e79d8a330ef0e68e7262642a8ea21a8c.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_7b393f38a8585bbe20782664bb86c01f.addLayer(e.layer);
#             });
#
#
#
#
#
#             var geocoderOpts_geocoder_2e889989d0e3b39bf510aa2e35aa41ae = {
#   &quot;collapsed&quot;: true,
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;defaultMarkGeocode&quot;: true,
#   &quot;zoom&quot;: 11,
#   &quot;provider&quot;: &quot;nominatim&quot;,
#   &quot;providerOptions&quot;: {
# },
# };
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_2e889989d0e3b39bf510aa2e35aa41ae = geocoderOpts_geocoder_2e889989d0e3b39bf510aa2e35aa41ae[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_2e889989d0e3b39bf510aa2e35aa41ae = L.Control.Geocoder[ geocoderName_geocoder_2e889989d0e3b39bf510aa2e35aa41ae ](
#                 geocoderOpts_geocoder_2e889989d0e3b39bf510aa2e35aa41ae[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_2e889989d0e3b39bf510aa2e35aa41ae[&quot;geocoder&quot;] = customGeocoder_geocoder_2e889989d0e3b39bf510aa2e35aa41ae;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_2e889989d0e3b39bf510aa2e35aa41ae
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_2e889989d0e3b39

# %% [markdown]
# ## Compare soil properties by region
#
# Let's extract actual values at our reference locations to see how different Missouri regions compare.

# %%
print("Soil Properties by Region:")
print("=" * 70)
print(f"{'Region':<30} {'Clay %':<12} {'OC (g/kg)':<12} {'pH':<10}")
print("-" * 70)

for name, coords in landmarks.items():
    point = ee.Geometry.Point(coords)
    
    clay_val = clay.reduceRegion(
        reducer=ee.Reducer.first(),
        geometry=point,
        scale=250
    ).get('b0').getInfo()
    
    oc_val = organic_carbon.reduceRegion(
        reducer=ee.Reducer.first(),
        geometry=point,
        scale=250
    ).get('b0').getInfo()
    
    ph_val = ph.reduceRegion(
        reducer=ee.Reducer.first(),
        geometry=point,
        scale=250
    ).get('b0').getInfo()
    
    oc_actual = oc_val / 10
    ph_actual = ph_val / 10
    
    print(f"{name:<30} {clay_val:<12} {oc_actual:<12.1f} {ph_actual:<10.1f}")

print("=" * 70)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Soil Properties by Region:
# ======================================================================
# Region                         Clay %       OC (g/kg)    pH
# ----------------------------------------------------------------------
# Northern Plains (Macon Co)     23           0.7          5.2
# Ozarks (Shannon Co)            15           0.3          6.3
# Bootheel (Dunklin Co)          17           0.2          5.9
# Missouri River Bottom          22           0.2          6.1
# ======================================================================

# %% [markdown]
# ## What patterns do you notice?
#
# Looking at the maps:
#
# **Clay content:**
# - Highest along the Missouri and Mississippi River floodplains
# - The Bootheel (SE Missouri) has heavy clay - historically swampland
# - Ozarks have lower clay - thin, rocky soils over limestone/dolomite
#
# **Organic carbon:**
# - Higher in northern Missouri - glaciated prairies accumulated organic matter
# - Lower in the Ozarks - thin soils, forest rather than prairie
# - Moderate in bottomlands - flooded too often to build up
#
# **Soil pH:**
# - More acidic in the Ozarks (high rainfall + forest)
# - More neutral in the glaciated north
# - River bottoms can be more alkaline (calcium from flooding)
#
# **Connection to land use:**
# - Row crops (corn, soybeans) dominate the deep, fertile soils of northern Missouri
# - The Ozarks are mostly forest and pasture - soils too thin for cultivation
# - The Bootheel grows rice, cotton, and soybeans suited to heavy clay

# %% [markdown]
# ## Try it yourself
#
# Ideas to explore:
#
# 1. **Your home county**: Change the county filter to examine soils where you grew up. How do the patterns match what you remember?
#
# 2. **Deeper soil layers**: The data has layers at 0, 10, 30, 60, 100, 200 cm depth. Try `select("b30")` or `select("b100")` to see how properties change with depth.
#
# 3. **Sand content**: Load the sand dataset and compare to clay. Where is soil sandy? How does that relate to crop patterns?
#    ```python
#    sand = ee.Image("OpenLandMap/SOL/SOL_SAND-WFRACTION_USDA-3A1A1A_M/v02").select("b0")
#    ```
#
# 4. **Soil texture classes**: Load the texture classification:
#    ```python
#    texture = ee.Image("OpenLandMap/SOL/SOL_TEXTURE-CLASS_USDA-TT_M/v02").select("b0")
#    # Classes: 1=Clay, 2=Silty Clay, 3=Sandy Clay, 4=Clay Loam, etc.
#    ```
#
# 5. **Compare states**: How do Missouri soils compare to Iowa (more glaciated) or Arkansas (more Ozark-like)?
#
# 6. **Historical perspective**: The Bootheel was drained in the early 1900s. Look at historical maps - how did converting swamp to farmland change the landscape?
#
# 7. **Satellite imagery overlay**: Load a Sentinel-2 image and compare visible soil color to the mapped properties. Do dark soils really have more organic carbon?
