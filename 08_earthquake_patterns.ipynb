# %% [markdown]
# ## Notebook 8: Global Earthquake Patterns
#
# **Thousands of earthquakes happen every day. Where are they, and what patterns emerge?**
#
# Right now, as you read this, seismometers around the world are recording ground motion. Most earthquakes are too small to feel, but they reveal something profound: the Earth's surface is broken into plates that are constantly moving, colliding, and sliding past each other.
#
# In this notebook, we'll:
#
# - Map recent earthquakes worldwide and see plate boundaries emerge
# - Explore magnitude patterns - why are big earthquakes rare?
# - Look at earthquake depth - what does it tell us about geology?
# - Zoom into the San Andreas Fault and the New Madrid Seismic Zone (near Missouri!)
#
# Data comes from the **USGS National Earthquake Information Center (NEIC)**, which monitors earthquakes globally using a network of thousands of seismometers.

# %% [markdown]
# ## Setup
#
# Same initialization as previous notebooks, plus we'll fetch earthquake data from the USGS API.

# %%
# %pip install -q geemap folium
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import ee
import json
import requests
from datetime import datetime, timedelta

# Initialize Earth Engine
PROJECT = "eeps-geospatial"
BUCKET = "wustl-eeps-edc"
ee.Initialize(project=PROJECT)

import geemap.foliumap as geemap

# Depth thresholds (km)
SHALLOW_MAX = 70
INTERMEDIATE_MAX = 300

print("Ready!")

# %% [markdown]
# ## How earthquakes are detected and cataloged
#
# **Seismometers** are sensitive instruments that detect ground motion. A global network of thousands of stations continuously records vibrations.
#
# When an earthquake occurs:
# 1. Seismic waves travel outward from the source (hypocenter)
# 2. Multiple stations detect the waves at slightly different times
# 3. Computers analyze arrival times to calculate location and depth
# 4. Amplitude of shaking determines magnitude
#
# **Key terms:**
# - **Magnitude**: Logarithmic measure of energy released (each unit = ~32x more energy)
# - **Depth**: Distance below surface to the rupture point
# - **Hypocenter**: The actual 3D location where rupture begins
# - **Epicenter**: The point on the surface directly above the hypocenter
#
# **Depth categories:**
# | Depth | Classification | Typical setting |
# |-------|---------------|----------------|
# | 0-70 km | Shallow | Most earthquakes; all fault types |
# | 70-300 km | Intermediate | Subduction zones |
# | 300-700 km | Deep | Subducting slabs only |

# %% [markdown]
# ## Fetch earthquake data from USGS
#
# We'll use the USGS Earthquake API to get recent earthquakes. The API returns GeoJSON that we can convert to Earth Engine FeatureCollections for mapping.

# %%
# Fetch earthquakes from the past 30 days, M4+
end_date = datetime.now().strftime('%Y-%m-%d')
start_date = (datetime.now() - timedelta(days=30)).strftime('%Y-%m-%d')

url = (
    f"https://earthquake.usgs.gov/fdsnws/event/1/query"
    f"?format=geojson&starttime={start_date}&endtime={end_date}"
    f"&minmagnitude=4.0&limit=5000&orderby=time"
)
response = requests.get(url, timeout=60)
data = response.json()

earthquakes = []
for feature in data['features']:
    props = feature['properties']
    coords = feature['geometry']['coordinates']
    earthquakes.append({
        'longitude': coords[0],
        'latitude': coords[1],
        'depth': coords[2],
        'magnitude': props.get('mag'),
        'place': props.get('place', 'Unknown'),
        'time': props.get('time'),
    })

print(f"Fetched {len(earthquakes)} earthquakes")

print("\nRecent significant earthquakes:")
for eq in earthquakes[:5]:
    print(f"  M{eq['magnitude']:.1f} - {eq['place']} (depth: {eq['depth']:.0f} km)")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Fetching earthquakes from 2025-12-31 to 2026-01-30...
# Fetched 780 earthquakes (M4.0+)
#
# Recent significant earthquakes:
#   M4.9 - 25 km W of Bantogon, Philippines (depth: 10 km)
#   M4.6 - 25 km WSW of Bantogon, Philippines (depth: 10 km)
#   M4.6 - 27 km SSE of Crucecita, Mexico (depth: 10 km)
#   M4.6 - Banda Sea (depth: 147 km)
#   M4.4 - 133 km SW of Kokopo, Papua New Guinea (depth: 156 km)

# %%
# Convert to Earth Engine FeatureCollection
features = []
for eq in earthquakes:
    if eq['magnitude'] is None:
        continue
    point = ee.Geometry.Point([eq['longitude'], eq['latitude']])
    features.append(ee.Feature(point, {
        'magnitude': eq['magnitude'],
        'depth': eq['depth'],
        'place': eq['place'],
        'time': eq['time']
    }))

eq_fc = ee.FeatureCollection(features)
print(f"Created FeatureCollection with {eq_fc.size().getInfo()} earthquakes")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Created FeatureCollection with 780 earthquakes

# %% [markdown]
# ## Global view: Where do earthquakes occur?
#
# Let's map all M4+ earthquakes from the past 30 days. We'll color them by depth:
# - **Red/Orange**: Shallow (0-70 km) - most dangerous, cause the most damage
# - **Yellow/Green**: Intermediate (70-300 km)
# - **Blue**: Deep (>300 km) - rarely felt at surface
#
# Look for the **"Ring of Fire"** around the Pacific Ocean!

# %%
m1 = geemap.Map(center=[20, 0], zoom=2)

shallow = eq_fc.filter(ee.Filter.lt('depth', SHALLOW_MAX))
intermediate = eq_fc.filter(ee.Filter.And(
    ee.Filter.gte('depth', SHALLOW_MAX),
    ee.Filter.lt('depth', INTERMEDIATE_MAX)
))
deep = eq_fc.filter(ee.Filter.gte('depth', INTERMEDIATE_MAX))

m1.addLayer(deep, {'color': '0000FF'}, 'Deep (>300 km)', True)
m1.addLayer(intermediate, {'color': '00FF00'}, 'Intermediate (70-300 km)', True)
m1.addLayer(shallow, {'color': 'FF0000'}, 'Shallow (<70 km)', True)

print(f"Shallow: {shallow.size().getInfo()} | Intermediate: {intermediate.size().getInfo()} | Deep: {deep.size().getInfo()}")
m1
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Shallow: 517 | Intermediate: 215 | Deep: 48
#
# Notice how earthquakes trace out the tectonic plate boundaries!
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7bb3b12cd8a7815ae899a870d4954286 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7bb3b12cd8a7815ae899a870d4954286&quot; &gt;&lt;/div&gt;
#
#
#
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7bb3b12cd8a7815ae899a870d4954286 = L.map(
#                 &quot;map_7bb3b12cd8a7815ae899a870d4954286&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;eeInitialize&quot;: true,
#   &quot;addGoogleMap&quot;: false,
#   &quot;pluginLatlngpopup&quot;: false,
#   &quot;pluginFullscreen&quot;: true,
#   &quot;pluginDraw&quot;: true,
#   &quot;DrawExport&quot;: false,
#   &quot;pluginMinimap&quot;: false,
#   &quot;locateControl&quot;: false,
#   &quot;searchControl&quot;: true,
#   &quot;basemap&quot;: &quot;OpenStreetMap&quot;,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3c17739a846eab5f0afb4a46b85712ba = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;OpenStreetMap&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3c17739a846eab5f0afb4a46b85712ba.addTo(map_7bb3b12cd8a7815ae899a870d4954286);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_7bb3b12cd8a7815ae899a870d4954286);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#                 // FeatureGroup is to store editable layers.
#                 var drawnItems_draw_control_aeaf8f50da16543af38402fb58d97386 =
#                     new L.featureGroup().addTo(
#                         map_7bb3b12cd8a7815ae899a870d4954286
#                     );
#
#             options.edit.featureGroup = drawnItems_draw_control_aeaf8f50da16543af38402fb58d97386;
#             var draw_control_aeaf8f50da16543af38402fb58d97386 = new L.Control.Draw(
#                 options
#             ).addTo( map_7bb3b12cd8a7815ae899a870d4954286 );
#             map_7bb3b12cd8a7815ae899a870d4954286.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_aeaf8f50da16543af38402fb58d97386.addLayer(layer);
#             });
#             map_7bb3b12cd8a7815ae899a870d4954286.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_aeaf8f50da16543af38402fb58d97386.addLayer(e.layer);
#             });
#
#
#
#
#
#             var geocoderOpts_geocoder_739b0eb6a20da748437b786939052d2b = {
#   &quot;collapsed&quot;: true,
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;defaultMarkGeocode&quot;: true,
#   &quot;zoom&quot;: 11,
#   &quot;provider&quot;: &quot;nominatim&quot;,
#   &quot;providerOptions&quot;: {
# },
# };
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_739b0eb6a20da748437b786939052d2b = geocoderOpts_geocoder_739b0eb6a20da748437b786939052d2b[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_739b0eb6a20da748437b786939052d2b = L.Control.Geocoder[ geocoderName_geocoder_739b0eb6a20da748437b786939052d2b ](
#                 geocoderOpts_geocoder_739b0eb6a20da748437b786939052d2b[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_739b0eb6a20da748437b786939052d2b[&quot;geocoder&quot;] = customGeocoder_geocoder_739b0eb6a20da748437b786939052d2b;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_739b0eb6a20da748437b786939052d2b
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_739b0eb6a20da748437b786939052d2b[&#x27;zoom&#x27;] || map_7bb3b12cd8a7815ae899a870d4954286.getZoom();
#                 map_7bb3b1

# %% [markdown]
# ## What patterns do you see?
#
# The earthquake locations reveal **plate tectonics** in action:
#
# - **Ring of Fire**: The Pacific Plate is subducting under surrounding plates, creating the most seismically active zone on Earth
# - **Mid-Atlantic Ridge**: Earthquakes along the spreading center where plates move apart
# - **Alpine-Himalayan Belt**: Collision zone from Mediterranean to Indonesia
# - **Stable interiors**: Very few earthquakes in the middle of continents (with exceptions!)
#
# **Depth patterns:**
# - Shallow earthquakes occur everywhere plates interact
# - Deep earthquakes ONLY occur at subduction zones (where oceanic crust dives into the mantle)

# %% [markdown]
# ## Zoom in: US West Coast and San Andreas Fault
#
# The San Andreas Fault is a **transform boundary** where the Pacific Plate slides past the North American Plate. This creates frequent moderate earthquakes and occasional devastating ones.
#
# Let's look at recent earthquakes along the West Coast.

# %%
# Fetch more earthquakes for US West Coast
url = (
    f"https://earthquake.usgs.gov/fdsnws/event/1/query"
    f"?format=geojson&starttime={start_date}&endtime={end_date}"
    f"&minmagnitude=2.5&limit=2000&orderby=time"
)
response = requests.get(url, timeout=60)
data = response.json()

west_coast_filtered = []
for feature in data['features']:
    coords = feature['geometry']['coordinates']
    lon, lat = coords[0], coords[1]
    if -125 <= lon <= -114 and 32 <= lat <= 42:
        props = feature['properties']
        west_coast_filtered.append({
            'longitude': lon,
            'latitude': lat,
            'depth': coords[2],
            'magnitude': props.get('mag'),
            'place': props.get('place', 'Unknown'),
            'time': props.get('time'),
        })

print(f"Fetched {len(west_coast_filtered)} earthquakes in West Coast region")

# Convert to FeatureCollection
wc_features = []
for eq in west_coast_filtered:
    if eq['magnitude'] is None:
        continue
    point = ee.Geometry.Point([eq['longitude'], eq['latitude']])
    wc_features.append(ee.Feature(point, {
        'magnitude': eq['magnitude'],
        'depth': eq['depth'],
        'place': eq['place'],
        'time': eq['time']
    }))
wc_fc = ee.FeatureCollection(wc_features)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Found 114 earthquakes (M2.5+) in West Coast region

# %%
m2 = geemap.Map(center=[37, -120], zoom=6)

small = wc_fc.filter(ee.Filter.lt('magnitude', 3.0))
medium = wc_fc.filter(ee.Filter.And(
    ee.Filter.gte('magnitude', 3.0),
    ee.Filter.lt('magnitude', 4.0)
))
large = wc_fc.filter(ee.Filter.gte('magnitude', 4.0))

m2.addLayer(small, {'color': 'FFFF00'}, 'M2.5-3.0 (small)', True)
m2.addLayer(medium, {'color': 'FFA500'}, 'M3.0-4.0 (moderate)', True)
m2.addLayer(large, {'color': 'FF0000'}, 'M4.0+ (significant)', True)

sf = ee.Geometry.Point([-122.4194, 37.7749])
la = ee.Geometry.Point([-118.2437, 34.0522])
m2.addLayer(sf, {'color': 'white'}, 'San Francisco')
m2.addLayer(la, {'color': 'white'}, 'Los Angeles')
m2
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Yellow = small (M2.5-3) | Orange = moderate (M3-4) | Red = significant (M4+)
#
# Look for the linear pattern along the San Andreas Fault!
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ed5b4d4ac4841c456d752e2817a91c0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ed5b4d4ac4841c456d752e2817a91c0&quot; &gt;&lt;/div&gt;
#
#
#
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ed5b4d4ac4841c456d752e2817a91c0 = L.map(
#                 &quot;map_3ed5b4d4ac4841c456d752e2817a91c0&quot;,
#                 {
#                     center: [37.0, -120.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;eeInitialize&quot;: true,
#   &quot;addGoogleMap&quot;: false,
#   &quot;pluginLatlngpopup&quot;: false,
#   &quot;pluginFullscreen&quot;: true,
#   &quot;pluginDraw&quot;: true,
#   &quot;DrawExport&quot;: false,
#   &quot;pluginMinimap&quot;: false,
#   &quot;locateControl&quot;: false,
#   &quot;searchControl&quot;: true,
#   &quot;basemap&quot;: &quot;OpenStreetMap&quot;,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3c17739a846eab5f0afb4a46b85712ba = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;OpenStreetMap&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3c17739a846eab5f0afb4a46b85712ba.addTo(map_3ed5b4d4ac4841c456d752e2817a91c0);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_3ed5b4d4ac4841c456d752e2817a91c0);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#                 // FeatureGroup is to store editable layers.
#                 var drawnItems_draw_control_012a71e39ee2fd4f69e5670512ce8725 =
#                     new L.featureGroup().addTo(
#                         map_3ed5b4d4ac4841c456d752e2817a91c0
#                     );
#
#             options.edit.featureGroup = drawnItems_draw_control_012a71e39ee2fd4f69e5670512ce8725;
#             var draw_control_012a71e39ee2fd4f69e5670512ce8725 = new L.Control.Draw(
#                 options
#             ).addTo( map_3ed5b4d4ac4841c456d752e2817a91c0 );
#             map_3ed5b4d4ac4841c456d752e2817a91c0.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_012a71e39ee2fd4f69e5670512ce8725.addLayer(layer);
#             });
#             map_3ed5b4d4ac4841c456d752e2817a91c0.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_012a71e39ee2fd4f69e5670512ce8725.addLayer(e.layer);
#             });
#
#
#
#
#
#             var geocoderOpts_geocoder_94e6f570ebc69bc82abf0c5572f7d829 = {
#   &quot;collapsed&quot;: true,
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;defaultMarkGeocode&quot;: true,
#   &quot;zoom&quot;: 11,
#   &quot;provider&quot;: &quot;nominatim&quot;,
#   &quot;providerOptions&quot;: {
# },
# };
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_94e6f570ebc69bc82abf0c5572f7d829 = geocoderOpts_geocoder_94e6f570ebc69bc82abf0c5572f7d829[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_94e6f570ebc69bc82abf0c5572f7d829 = L.Control.Geocoder[ geocoderName_geocoder_94e6f570ebc69bc82abf0c5572f7d829 ](
#                 geocoderOpts_geocoder_94e6f570ebc69bc82abf0c5572f7d829[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_94e6f570ebc69bc82abf0c5572f7d829[&quot;geocoder&quot;] = customGeocoder_geocoder_94e6f570ebc69bc82abf0c5572f7d829;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_94e6f570ebc69bc82abf0c5572f7d829
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_94e6f570ebc69bc82abf0c5572f7d829[&#x27;zoom&#x27;] || map_3ed5b4d4ac4841c456d752e2817a91c0.getZoom();
#                 map_3ed

# %% [markdown]
# ## Zoom in: New Madrid Seismic Zone
#
# **Why do earthquakes happen in Missouri?**
#
# The New Madrid Seismic Zone is one of the most significant earthquake zones in the central US. In 1811-1812, a series of massive earthquakes (estimated M7.5-8.0) struck here - so powerful they:
# - Rang church bells in Boston, 1,000 miles away
# - Caused the Mississippi River to temporarily flow backwards
# - Created Reelfoot Lake in Tennessee
#
# This zone exists because of an ancient **failed rift** - a crack in the Earth's crust from 500 million years ago that never fully developed. The buried fault zone is still active today.
#
# Let's see recent earthquakes in the region.

# %%
# Fetch earthquakes for New Madrid region - past year, lower magnitude threshold
nm_start = (datetime.now() - timedelta(days=365)).strftime('%Y-%m-%d')

url = (
    f"https://earthquake.usgs.gov/fdsnws/event/1/query"
    f"?format=geojson&starttime={nm_start}&endtime={end_date}"
    f"&minmagnitude=2.0&limit=3000&orderby=time"
)
response = requests.get(url, timeout=60)
data = response.json()

new_madrid_filtered = []
for feature in data['features']:
    coords = feature['geometry']['coordinates']
    lon, lat = coords[0], coords[1]
    if -92 <= lon <= -88 and 34 <= lat <= 38:
        props = feature['properties']
        new_madrid_filtered.append({
            'longitude': lon,
            'latitude': lat,
            'depth': coords[2],
            'magnitude': props.get('mag'),
            'place': props.get('place', 'Unknown'),
            'time': props.get('time'),
        })

print(f"Fetched {len(new_madrid_filtered)} earthquakes in New Madrid region (past year)")

print("\nLargest recent earthquakes:")
sorted_eq = sorted(new_madrid_filtered, key=lambda x: x['magnitude'] or 0, reverse=True)
for eq in sorted_eq[:5]:
    print(f"  M{eq['magnitude']:.1f} - {eq['place']}")

# Convert to FeatureCollection
nm_features = []
for eq in new_madrid_filtered:
    if eq['magnitude'] is None:
        continue
    point = ee.Geometry.Point([eq['longitude'], eq['latitude']])
    nm_features.append(ee.Feature(point, {
        'magnitude': eq['magnitude'],
        'depth': eq['depth'],
        'place': eq['place'],
        'time': eq['time']
    }))
nm_fc = ee.FeatureCollection(nm_features)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Found 3 earthquakes (M2.0+) in New Madrid region (past year)
#
# Largest recent earthquakes:
#   M2.5 - 12 km WNW of Newbern, Tennessee
#   M2.4 - 4 km SSW of Caruthersville, Missouri
#   M2.2 - 2 km W of Lynn, Arkansas

# %%
m3 = geemap.Map(center=[36.5, -89.5], zoom=7)

m3.addLayer(nm_fc, {'color': 'FF0000'}, 'New Madrid Earthquakes (past year)')

memphis = ee.Geometry.Point([-90.0490, 35.1495])
stlouis = ee.Geometry.Point([-90.1994, 38.6270])
m3.addLayer(memphis, {'color': 'blue'}, 'Memphis')
m3.addLayer(stlouis, {'color': 'blue'}, 'St. Louis')
m3
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# The New Madrid Seismic Zone runs from NE Arkansas through SE Missouri
# Memphis and St. Louis are both at risk from a New Madrid earthquake
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_32d4794671f829ca3a991210e8764f37 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_32d4794671f829ca3a991210e8764f37&quot; &gt;&lt;/div&gt;
#
#
#
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_32d4794671f829ca3a991210e8764f37 = L.map(
#                 &quot;map_32d4794671f829ca3a991210e8764f37&quot;,
#                 {
#                     center: [36.5, -89.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;eeInitialize&quot;: true,
#   &quot;addGoogleMap&quot;: false,
#   &quot;pluginLatlngpopup&quot;: false,
#   &quot;pluginFullscreen&quot;: true,
#   &quot;pluginDraw&quot;: true,
#   &quot;DrawExport&quot;: false,
#   &quot;pluginMinimap&quot;: false,
#   &quot;locateControl&quot;: false,
#   &quot;searchControl&quot;: true,
#   &quot;basemap&quot;: &quot;OpenStreetMap&quot;,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3c17739a846eab5f0afb4a46b85712ba = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;OpenStreetMap&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3c17739a846eab5f0afb4a46b85712ba.addTo(map_32d4794671f829ca3a991210e8764f37);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_32d4794671f829ca3a991210e8764f37);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#                 // FeatureGroup is to store editable layers.
#                 var drawnItems_draw_control_25246cfa5567d6ac7ce1b863b106cc8a =
#                     new L.featureGroup().addTo(
#                         map_32d4794671f829ca3a991210e8764f37
#                     );
#
#             options.edit.featureGroup = drawnItems_draw_control_25246cfa5567d6ac7ce1b863b106cc8a;
#             var draw_control_25246cfa5567d6ac7ce1b863b106cc8a = new L.Control.Draw(
#                 options
#             ).addTo( map_32d4794671f829ca3a991210e8764f37 );
#             map_32d4794671f829ca3a991210e8764f37.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_25246cfa5567d6ac7ce1b863b106cc8a.addLayer(layer);
#             });
#             map_32d4794671f829ca3a991210e8764f37.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_25246cfa5567d6ac7ce1b863b106cc8a.addLayer(e.layer);
#             });
#
#
#
#
#
#             var geocoderOpts_geocoder_e402edd0e68819133328b9b1ac4b11ff = {
#   &quot;collapsed&quot;: true,
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;defaultMarkGeocode&quot;: true,
#   &quot;zoom&quot;: 11,
#   &quot;provider&quot;: &quot;nominatim&quot;,
#   &quot;providerOptions&quot;: {
# },
# };
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_e402edd0e68819133328b9b1ac4b11ff = geocoderOpts_geocoder_e402edd0e68819133328b9b1ac4b11ff[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_e402edd0e68819133328b9b1ac4b11ff = L.Control.Geocoder[ geocoderName_geocoder_e402edd0e68819133328b9b1ac4b11ff ](
#                 geocoderOpts_geocoder_e402edd0e68819133328b9b1ac4b11ff[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_e402edd0e68819133328b9b1ac4b11ff[&quot;geocoder&quot;] = customGeocoder_geocoder_e402edd0e68819133328b9b1ac4b11ff;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_e402edd0e68819133328b9b1ac4b11ff
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_e402edd0e68819133328b9b1ac4b11ff[&#x27;zoom&#x27;] || map_32d4794671f829ca3a991210e8764f37.getZoom();
#                 map_32d4

# %% [markdown]
# ## Magnitude-frequency relationship
#
# One of the most important discoveries in seismology: **small earthquakes are exponentially more common than large ones**.
#
# This follows the **Gutenberg-Richter Law**: for every increase of 1 in magnitude, there are roughly 10 times fewer earthquakes.
#
# Globally, on average:
# - M8+: ~1 per year
# - M7-7.9: ~15 per year
# - M6-6.9: ~150 per year
# - M5-5.9: ~1,500 per year
# - M4-4.9: ~15,000 per year
#
# Let's plot this relationship with our data.

# %%
# Simple text-based histogram of magnitudes
mag_bins = {}
for eq in earthquakes:
    if eq['magnitude'] is not None:
        mag_bin = int(eq['magnitude'])  # Round down to nearest integer
        mag_bins[mag_bin] = mag_bins.get(mag_bin, 0) + 1

print("Magnitude Distribution (past 30 days, M4+ globally):")
print("=" * 60)
print(f"{'Magnitude':<12} {'Count':<10} {'Visual'}")
print("-" * 60)

for mag in sorted(mag_bins.keys()):
    count = mag_bins[mag]
    bar = '█' * min(count // 5, 40)  # Scale for display
    print(f"M{mag}.0-{mag}.9    {count:<10} {bar}")

print("-" * 60)
print(f"Total: {len(earthquakes)} earthquakes")
print("\nNotice: Each magnitude level has roughly 10x fewer earthquakes!")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Magnitude Distribution (past 30 days, M4+ globally):
# ============================================================
# Magnitude    Count      Visual
# ------------------------------------------------------------
# M4.0-4.9    604        ████████████████████████████████████████
# M5.0-5.9    165        █████████████████████████████████
# M6.0-6.9    11         ██
# ------------------------------------------------------------
# Total: 780 earthquakes
#
# Notice: Each magnitude level has roughly 10x fewer earthquakes!

# %% [markdown]
# ## Depth distribution
#
# Earthquake depth tells us about the geological setting:
#
# - **Shallow (0-70 km)**: All types of faults; most damaging because energy reaches surface easily
# - **Intermediate (70-300 km)**: Only at subduction zones where oceanic crust dives down
# - **Deep (300-700 km)**: Only at mature subduction zones (like under South America or Japan)
#
# Below ~700 km, rock becomes too hot and plastic to fracture - no earthquakes occur.

# %%
depth_bins = {'Shallow (0-70 km)': 0, 'Intermediate (70-300 km)': 0, 'Deep (>300 km)': 0}

for eq in earthquakes:
    depth = eq['depth']
    if depth < SHALLOW_MAX:
        depth_bins['Shallow (0-70 km)'] += 1
    elif depth < INTERMEDIATE_MAX:
        depth_bins['Intermediate (70-300 km)'] += 1
    else:
        depth_bins['Deep (>300 km)'] += 1

total = sum(depth_bins.values())

print("Depth Distribution (past 30 days, M4+ globally):")
print("=" * 60)

for category, count in depth_bins.items():
    pct = count / total * 100
    bar = '█' * int(pct / 2)
    print(f"{category:<25} {count:>6} ({pct:5.1f}%) {bar}")

print("=" * 60)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Depth Distribution (past 30 days, M4+ globally):
# ============================================================
# Shallow (0-70 km)            517 ( 66.3%) █████████████████████████████████
# Intermediate (70-300 km)     215 ( 27.6%) █████████████
# Deep (>300 km)                48 (  6.2%) ███
# ============================================================
#
# Most earthquakes are shallow - they occur at all plate boundaries.
# Deep earthquakes only happen at subduction zones.

# %% [markdown]
# ## Key takeaways
#
# **Spatial patterns:**
# - Earthquakes clearly define tectonic plate boundaries
# - The "Ring of Fire" (Pacific rim) has the most earthquakes
# - Continental interiors are mostly quiet, with important exceptions (like New Madrid)
#
# **Magnitude patterns:**
# - Small earthquakes are exponentially more common than large ones
# - A M7 releases ~32x more energy than a M6
# - We can't predict when large earthquakes will occur
#
# **Depth patterns:**
# - ~90% of earthquakes are shallow (<70 km)
# - Deep earthquakes only occur where cold oceanic crust subducts
# - Shallow earthquakes cause the most damage
#
# **Missouri relevance:**
# - The New Madrid Seismic Zone is a real hazard
# - A repeat of the 1811-1812 earthquakes would be catastrophic today
# - This is why earthquake preparedness matters even in the Midwest!

# %% [markdown]
# ## Try it yourself
#
# Ideas to explore:
#
# 1. **Change the magnitude threshold**: What happens if you look at M5+ only? M3+? How does the map change?
#
# 2. **Longer time range**: Fetch a full year of data to see more patterns. Be patient - this fetches more data!
#    ```python
#    start_date = '2024-01-01'
#    end_date = '2024-12-31'
#    ```
#
# 3. **Different regions**: Zoom into other interesting areas:
#    - Japan: `center=[36, 140], zoom=5`
#    - Indonesia: `center=[-5, 120], zoom=4`
#    - Alaska: `center=[64, -150], zoom=4`
#    - Mediterranean: `center=[38, 20], zoom=5`
#
# 4. **Aftershock sequences**: After a major earthquake, look for clustering of smaller events in the same area. Find a recent M7+ and see its aftershocks.
#
# 5. **Compare years**: Is 2024 more or less active than 2023? Fetch data for different years and compare totals.
#
# 6. **Oklahoma induced seismicity**: Oklahoma had a huge increase in earthquakes due to wastewater injection from oil/gas operations. Compare 2010 vs 2015 for that region.
#    ```python
#    # Oklahoma bounding box
#    -103 <= longitude <= -94 and 33.5 <= latitude <= 37
#    ```
#
# 7. **Historical earthquakes**: The USGS catalog goes back decades. Look at the 1989 Loma Prieta or 1994 Northridge earthquakes and their aftershocks.
